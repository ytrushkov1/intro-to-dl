# %% [markdown]
# ### Your very own neural network
#
# In this notebook, we're going to build a neural network using naught but pure numpy and steel nerves. It's going to be fun, I promise!
#
# ![img](https://s27.postimg.org/vpui4r5n7/cartoon-2029952_960_720.png)

# %%
import sys
import itertools

# %%
# use the preloaded keras datasets and models
! mkdir -p ~/.keras/datasets
! mkdir -p ~/.keras/models
! ln -s $(realpath ../readonly/keras/datasets/*) ~/.keras/datasets/
! ln -s $(realpath ../readonly/keras/models/*) ~/.keras/models/
# Out:
# realpath: '../readonly/keras/datasets/*': No such file or directory
# ln: failed to create symbolic link './datasets': File exists
# realpath: '../readonly/keras/models/*': No such file or directory
# ln: failed to create symbolic link './models': File exists

# %%
from __future__ import print_function
import numpy as np
np.random.seed(42)

# %%
from IPython.display import clear_output

# %% [markdown]
# Here goes our main class: a layer that can .forward() and .backward().

# %%
class Layer:
    """
    A building block. Each layer is capable of performing two things:
    
    - Process input to get output:           output = layer.forward(input)
    
    - Propagate gradients through itself:    grad_input = layer.backward(input, grad_output)
    
    Some layers also have learnable parameters which they update during layer.backward.
    """
    def __init__(self):
        """Here you can initialize layer parameters (if any) and auxiliary stuff."""
        # A dummy layer does nothing
        pass
    
    def forward(self, input):
        """
        Takes input data of shape [batch, input_units], returns output data [batch, output_units]
        """
        # A dummy layer just returns whatever it gets as input.
        return input

    def backward(self, input, grad_output):
        """
        Performs a backpropagation step through the layer, with respect to the given input.
        
        To compute loss gradients w.r.t input, you need to apply chain rule (backprop):
        
        d loss / d x  = (d loss / d layer) * (d layer / d x)
        
        Luckily, you already receive d loss / d layer as input, so you only need to multiply it by d layer / d x.
        
        If your layer has parameters (e.g. dense layer), you also need to update them here using d loss / d layer
        """
        # The gradient of a dummy layer is precisely grad_output, but we'll write it more explicitly
        num_units = input.shape[1]
        
        d_layer_d_input = np.eye(num_units)
        
        return np.dot(grad_output, d_layer_d_input) # chain rule

# %% [markdown]
# ### The road ahead
#
# We're going to build a neural network that classifies MNIST digits. To do so, we'll need a few building blocks:
# - Dense layer - a fully-connected layer, $f(X)=W \cdot X + \vec{b}$
# - ReLU layer (or any other nonlinearity you want)
# - Loss function - crossentropy
# - Backprop algorithm - a stochastic gradient descent with backpropageted gradients
#
# Let's approach them one at a time.

# %% [markdown]
# ### Nonlinearity layer
#
# This is the simplest layer you can get: it simply applies a nonlinearity to each element of your network.

# %%
class ReLU(Layer):
    def __init__(self):
        """ReLU layer simply applies elementwise rectified linear unit to all inputs"""
        pass
    
    def forward(self, input):
        """Apply elementwise ReLU to [batch, input_units] matrix"""
        # <your code. Try np.maximum>
        return np.maximum(0, input)
    
    def backward(self, input, grad_output):
        """Compute gradient of loss w.r.t. ReLU input"""
        relu_grad = input > 0
        return grad_output * relu_grad

# %%
# some tests
from util import eval_numerical_gradient
x = np.linspace(-1,1,10*32).reshape([10,32])
l = ReLU()
grads = l.backward(x,np.ones([10,32])/(32*10))
numeric_grads = eval_numerical_gradient(lambda x: l.forward(x).mean(), x=x)
assert np.allclose(grads, numeric_grads, rtol=1e-3, atol=0),\
    "gradient returned by your layer does not match the numerically computed gradient"

# %% [markdown]
# ### Dense layer
#
# Now let's build something more complicated. Unlike nonlinearity, a dense layer actually has something to learn.
#
# A dense layer applies affine transformation. In a vectorized form, it can be described as:
# $$f(X)= W \cdot X + \vec b $$
#
# Where
# * X is an object-feature matrix of shape [batch_size, num_features],
# * W is a weight matrix [num_features, num_outputs]
# * and b is a vector of num_outputs biases.
#
# Both W and b are initialized during layer creation and updated each time backward is called.

# %%
class Dense(Layer):
    def __init__(self, input_units, output_units, learning_rate=0.1):
        """
        A dense layer is a layer which performs a learned affine transformation:
        f(x) = <W*x> + b
        """
        self.learning_rate = learning_rate
        
        # initialize weights with small random numbers. We use normal initialization, 
        # but surely there is something better. Try this once you got it working: http://bit.ly/2vTlmaJ
        self.weights = np.random.randn(input_units, output_units)*0.01
        self.biases = np.zeros(output_units)
        
    def forward(self,input):
        """
        Perform an affine transformation:
        f(x) = <W*x> + b
        
        input shape: [batch, input_units]
        output shape: [batch, output units]
        """
        return input.dot(self.weights) + self.biases
    
    def backward(self,input,grad_output):
        
        # compute d f / d x = d f / d dense * d dense / d x
        # where d dense/ d x = weights transposed
        grad_input = grad_output.dot(self.weights.T)
        
        # compute gradient w.r.t. weights and biases
        grad_weights = input.T.dot(grad_output)
        grad_biases = np.sum(grad_output, axis=0)
        
        assert grad_weights.shape == self.weights.shape and grad_biases.shape == self.biases.shape
        # Here we perform a stochastic gradient descent step. 
        # Later on, you can try replacing that with something better.
        self.weights = self.weights - self.learning_rate * grad_weights
        self.biases = self.biases - self.learning_rate * grad_biases
        
        return grad_input

# %% [markdown]
# ### Testing the dense layer

# %%
l = Dense(128, 150)

assert -0.05 < l.weights.mean() < 0.05 and 1e-3 < l.weights.std() < 1e-1,\
    "The initial weights must have zero mean and small variance. "\
    "If you know what you're doing, remove this assertion."
assert -0.05 < l.biases.mean() < 0.05, "Biases must be zero mean. Ignore if you have a reason to do otherwise."

# To test the outputs, we explicitly set weights with fixed values. DO NOT DO THAT IN ACTUAL NETWORK!
l = Dense(3,4)

x = np.linspace(-1,1,2*3).reshape([2,3])
l.weights = np.linspace(-1,1,3*4).reshape([3,4])
l.biases = np.linspace(-1,1,4)

assert np.allclose(l.forward(x),np.array([[ 0.07272727,  0.41212121,  0.75151515,  1.09090909],
                                          [-0.90909091,  0.08484848,  1.07878788,  2.07272727]]))
print("Well done!")
# Out:
# Well done!

# %%
# To test the grads, we use gradients obtained via finite differences

from util import eval_numerical_gradient

x = np.linspace(-1,1,10*32).reshape([10,32])
l = Dense(32,64,learning_rate=0)

numeric_grads = eval_numerical_gradient(lambda x: l.forward(x).sum(),x)
grads = l.backward(x,np.ones([10,64]))

assert np.allclose(grads,numeric_grads,rtol=1e-3,atol=0), "input gradient does not match numeric grad"
print("Well done!")
# Out:
# Well done!

# %%
#test gradients w.r.t. params
def compute_out_given_wb(w,b):
    l = Dense(32,64,learning_rate=1)
    l.weights = np.array(w)
    l.biases = np.array(b)
    x = np.linspace(-1,1,10*32).reshape([10,32])
    return l.forward(x)
    
def compute_grad_by_params(w,b):
    l = Dense(32,64,learning_rate=1)
    l.weights = np.array(w)
    l.biases = np.array(b)
    x = np.linspace(-1,1,10*32).reshape([10,32])
    l.backward(x,np.ones([10,64]) / 10.)
    return w - l.weights, b - l.biases
    
w,b = np.random.randn(32,64), np.linspace(-1,1,64)

numeric_dw = eval_numerical_gradient(lambda w: compute_out_given_wb(w,b).mean(0).sum(),w )
numeric_db = eval_numerical_gradient(lambda b: compute_out_given_wb(w,b).mean(0).sum(),b )
grad_w,grad_b = compute_grad_by_params(w,b)

assert np.allclose(numeric_dw,grad_w,rtol=1e-3,atol=0), "weight gradient does not match numeric weight gradient"
assert np.allclose(numeric_db,grad_b,rtol=1e-3,atol=0), "weight gradient does not match numeric weight gradient"
print("Well done!")
# Out:
# Well done!

# %% [markdown]
# ### The loss function
#
# Since we want to predict probabilities, it would be logical for us to define softmax nonlinearity on top of our network and compute loss given predicted probabilities. However, there is a better way to do so.
#
# If you write down the expression for crossentropy as a function of softmax logits (a), you'll see:
#
# $$ loss = - log \space {e^{a_{correct}} \over {\underset i \sum e^{a_i} } } $$
#
# If you take a closer look, ya'll see that it can be rewritten as:
#
# $$ loss = - a_{correct} + log {\underset i \sum e^{a_i} } $$
#
# It's called Log-softmax and it's better than naive log(softmax(a)) in all aspects:
# * Better numerical stability
# * Easier to get derivative right
# * Marginally faster to compute
#
# So why not just use log-softmax throughout our computation and never actually bother to estimate probabilities.
#
# Here you are! We've defined the both loss functions for you so that you could focus on neural network part.

# %%
def softmax(logits, axis=1):
    '''stable softmax'''
    
    exps = np.exp(logits - np.max(logits, axis=axis, keepdims=True))
    return exps / np.sum(exps, axis=axis, keepdims=True)

# %%
def softmax_crossentropy_with_logits(logits, reference_answers):
    """Compute crossentropy from logits[batch,n_classes] and ids of correct answers"""
   
    # this is unstable code. I experienced numerical over and under flows
    logits = logits - logits.max(axis=1, keepdims=True)
    logits_for_answers = logits[np.arange(len(logits)),reference_answers]
    xentropy = - logits_for_answers + np.log(np.sum(np.exp(logits),axis=-1))
    
    return xentropy

# %%
def grad_softmax_crossentropy_with_logits(logits, reference_answers):
    """Compute crossentropy gradient from logits[batch,n_classes] and ids of correct answers"""
    ones_for_answers = np.zeros_like(logits)
    ones_for_answers[np.arange(len(logits)), reference_answers] = 1
        
    return (softmax(logits) - ones_for_answers) / logits.shape[0]

# %%
# Checks from the original task
logits = np.linspace(-1,1,500).reshape([50,10])
answers = np.arange(50)%10

grads = grad_softmax_crossentropy_with_logits(logits,answers)
numeric_grads = eval_numerical_gradient(lambda l: softmax_crossentropy_with_logits(l,answers).mean(),logits)

assert np.allclose(numeric_grads,grads,rtol=1e-3,atol=0), "The reference implementation has just failed. Someone has just changed the rules of math."

# %% [markdown]
# ### Full network
#
# Now let's combine what we've just built into a working neural network. As we announced, we're gonna use this monster to classify handwritten digits, so let's get them loaded.

# %% [markdown]
# We'll define network as a list of layers, each applied on top of previous one. In this setting, computing predictions and training becomes trivial.

# %%
def forward(network, X):
    """
    Compute activations of all network layers by applying them sequentially.
    Return a list of activations for each layer. 
    Make sure last activation corresponds to network logits.
    """
    activations = []
    input = X

    # <your code here>
    for layer in network:
        input = layer.forward(input)
        activations.append(input)
        
    assert len(activations) == len(network)
    return activations

def predict(network,X):
    """
    Compute network predictions.
    """
    logits = forward(network,X)[-1]
    return logits.argmax(axis=-1)

def train(network,X,y):
    """
    Train your network on a given batch of X and y.
    You first need to run forward to get all layer activations.
    Then you can run layer.backward going from last to first layer.
    
    After you called backward for all layers, all Dense layers have already made one gradient step.
    """
    
    # Get the layer activations
    layer_activations = forward(network,X)
    layer_inputs = [X]+layer_activations  #layer_input[i] is an input for network[i]
    logits = layer_activations[-1]
    
    # Compute the loss and the initial gradient
    loss = softmax_crossentropy_with_logits(logits,y)
    loss_grad = grad_softmax_crossentropy_with_logits(logits,y)
    
    # <your code: propagate gradients through the network>
    layer_inputs = layer_inputs[:-1]
    grad_output = loss_grad
    for layer, layer_input in reversed(list(zip(network,layer_inputs))):
        grad_output = layer.backward(layer_input, grad_output)
        
    return np.mean(loss)

# %% [markdown]
# Instead of tests, we provide you with a training loop that prints training and validation accuracies on every epoch.
#
# If your implementation of forward and backward are correct, your accuracy should grow from 90~93% to >97% with the default network.

# %% [markdown]
# ### Data
#
# As usual, we split data into minibatches, feed each such minibatch into the network and update weights.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from preprocessed_mnist import load_dataset
X_train, y_train, X_val, y_val, X_test, y_test = load_dataset(flatten=True)

plt.figure(figsize=[6,6])
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title("Label: %i"%y_train[i])
    plt.imshow(X_train[i].reshape([28,28]),cmap='gray');
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from tqdm import trange
def titerate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.random.permutation(len(inputs))
    for start_idx in trange(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]

# %%
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.random.permutation(len(inputs))
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# ### Training loop

# %%
network = []
network.append(Dense(X_train.shape[1],100))
network.append(ReLU())
network.append(Dense(100,200))
network.append(ReLU())
network.append(Dense(200,10))

# %%
# %%time 

train_log = []
val_log = []

for epoch in range(25):

    for x_batch,y_batch in titerate_minibatches(X_train,y_train,batchsize=32,shuffle=True):
        train(network,x_batch,y_batch)
    
    train_log.append(np.mean(predict(network,X_train)==y_train))
    val_log.append(np.mean(predict(network,X_val)==y_val))
    
    clear_output()
    print("Epoch",epoch)
    print("Train accuracy:",train_log[-1])
    print("Val accuracy:",val_log[-1])
    plt.plot(train_log,label='train accuracy')
    plt.plot(val_log,label='val accuracy')
    plt.legend(loc='best')
    plt.grid()
    plt.show()
# Out:
# Epoch 24
# Train accuracy: 0.99998
# Val accuracy: 0.9803
# CPU times: user 1min 51s, sys: 33.4 s, total: 2min 24s
# Wall time: 1min 13s

# %% [markdown]
# ### Peer-reviewed assignment
#
# Congradulations, you managed to get this far! There is just one quest left undone, and this time you'll get to choose what to do.
#
#
# #### Option I: initialization
# * Implement Dense layer with Xavier initialization as explained [here](http://bit.ly/2vTlmaJ)
#
# To pass this assignment, you must conduct an experiment showing how xavier initialization compares to default initialization on deep networks (5+ layers).
#
#
# #### Option II: regularization
# * Implement a version of Dense layer with L2 regularization penalty: when updating Dense Layer weights, adjust gradients to minimize
#
# $$ Loss = Crossentropy + \alpha \cdot \underset i \sum {w_i}^2 $$
#
# To pass this assignment, you must conduct an experiment showing if regularization mitigates overfitting in case of abundantly large number of neurons. Consider tuning $\alpha$ for better results.
#
# #### Option III: optimization
# * Implement a version of Dense layer that uses momentum/rmsprop or whatever method worked best for you last time.
#
# Most of those methods require persistent parameters like momentum direction or moving average grad norm, but you can easily store those params inside your layers.
#
# To pass this assignment, you must conduct an experiment showing how your chosen method performs compared to vanilla SGD.
#
# ### General remarks
# _Please read the peer-review guidelines before starting this part of the assignment._
#
# In short, a good solution is one that:
# * is based on this notebook
# * runs in the default course environment with Run All
# * its code doesn't cause spontaneous eye bleeding
# * its report is easy to read.
#
# _Formally we can't ban you from writing boring reports, but if you bored your reviewer to death, there's noone left alive to give you the grade you want._
#
#
# ### Bonus assignments
#
# As a bonus assignment (no points, just swag), consider implementing Batch Normalization ([guide](https://gab41.lab41.org/batch-normalization-what-the-hey-d480039a9e3b)) or Dropout ([guide](https://medium.com/@amarbudhiraja/https-medium-com-amarbudhiraja-learning-less-to-learn-better-dropout-in-deep-machine-learning-74334da4bfc5)). Note, however, that those "layers" behave differently when training and when predicting on test set.
#
# * Dropout:
#   * During training: drop units randomly with probability __p__ and multiply everything by __1/(1-p)__
#   * During final predicton: do nothing; pretend there's no dropout
#
# * Batch normalization
#   * During training, it substracts mean-over-batch and divides by std-over-batch and updates mean and variance.
#   * During final prediction, it uses accumulated mean and variance.

# %% [markdown]
# ### Peer-reviewed assignments

# %% [markdown]
# #### Option I: initialization

# %%
import datetime

# %%
class Dense1(Layer):
    def __init__(self, input_units, output_units, initializer='xavier', learning_rate=0.1, grad_clipping=0):
        """
        A dense layer is a layer which performs a learned affine transformation:
        f(x) = <W*x> + b
        """
        self.learning_rate = learning_rate
        self.grad_clipping = grad_clipping

        # initialize weights with small random numbers. 
        if initializer == 'normal':
            self.weights = np.random.randn(input_units, output_units) * 0.01
        elif initializer == 'xavier':
            self.weights = np.random.randn(input_units, output_units) * np.sqrt(2 / (input_units + output_units))
        else:
            raise ValueError('Wrong initializer parameter')
        self.biases = np.zeros(output_units)
        
    def forward(self, input):
        """
        Perform an affine transformation:
        f(x) = <W*x> + b
        
        input shape: [batch, input_units]
        output shape: [batch, output units]
        """
        return input.dot(self.weights) + self.biases
    
    def backward(self, input, grad_output):
        
        # compute d f / d x = d f / d dense * d dense / d x
        grad_input = grad_output.dot(self.weights.T)
        
        # compute gradient w.r.t. weights and biases
        grad_weights = input.T.dot(grad_output)
        grad_biases = np.sum(grad_output, axis=0)
        
        assert grad_weights.shape == self.weights.shape and grad_biases.shape == self.biases.shape
        
        # Here we perform a stochastic gradient descent step. 
        if self.grad_clipping:
            grad_weights = np.clip(grad_weights, -self.grad_clipping, self.grad_clipping)
            grad_biases = np.clip(grad_biases, -self.grad_clipping, self.grad_clipping)
        
        self.weights = self.weights - self.learning_rate * grad_weights
        self.biases = self.biases - self.learning_rate * grad_biases
        
        return grad_input

# %%
def build_and_train1(layer_sizes, initializer, lr, n_epochs, grad_clipping, logfile=sys.stdout):
            
    print('\n{}: Training with initializer = {}, lr = {} and gradient_clipping = {}, for n_epochs = {}'.format(
        datetime.datetime.now(), initializer, lr, grad_clipping, n_epochs), file=logfile)
    
    network = []
    network.append(Dense1(X_train.shape[1], layer_sizes[0],
                          initializer=initializer, learning_rate=lr, grad_clipping=grad_clipping))
    network.append(ReLU())
    for layer in range(len(layer_sizes)-1):
        network.append(Dense1(layer_sizes[layer], layer_sizes[layer+1],
                              initializer=initializer, learning_rate=lr, grad_clipping=grad_clipping))
        network.append(ReLU())
    network.append(Dense1(layer_sizes[-1], 10,
                          initializer=initializer, learning_rate=lr, grad_clipping=grad_clipping))

    train_log = []
    val_log = []

    for epoch in range(n_epochs):

        for x_batch,y_batch in iterate_minibatches(X_train,y_train,batchsize=32,shuffle=True):
            train(network,x_batch,y_batch)

        train_log.append(np.mean(predict(network,X_train)==y_train))
        val_log.append(np.mean(predict(network,X_val)==y_val))    
        print('{}: epoch = {:2d}, train acc = {:6.4f}, val acc = {:6.4f}'.format(
            datetime.datetime.now(), epoch, train_log[-1], val_log[-1]), file=logfile, flush=True)
        
    return train_log, val_log

def display_learning_curve1(ax, train_log, val_log, initializer, lr):
        
    ax.plot(train_log,label='train accuracy')
    ax.plot(val_log,label='val accuracy')
    ax.set_ylim(0.86, 1)
#     plt.legend(loc='best')
    ax.set_title('initializer = {}, lr = {}'.format(initializer, lr), fontsize=14)
    ax.text(0.5, 0.2, 'train acc = {:6.4f}\n   val acc = {:6.4f}'.format(train_log[-1], val_log[-1]),
            ha='left', va='bottom', fontsize=14, transform=ax.transAxes)
    ax.grid()
    plt.tight_layout()

# %% [markdown]
# ### Small network

# %%
# %%time
layer_sizes = [200] * 2

lrs = [0.07, 0.1, 0.3, 0.5]
initializers = ['normal', 'xavier']
grad_clippings = [0, 5]

n_epochs = 50

learning_curves = []
logfile_path = 'logs/notebook_' + datetime.datetime.now().strftime('%Y%m%d') + '.log'
with open(logfile_path, 'a') as logfile:
    for params in itertools.product(grad_clippings, initializers, lrs):
        grad_clipping, initializer, lr = params
        train_log, val_log = build_and_train1(layer_sizes,
                                              initializer, lr, n_epochs, grad_clipping=grad_clipping, logfile=logfile)

        learning_curves.append((train_log, val_log, params))
# Out:
# CPU times: user 1h 26min 11s, sys: 21min 24s, total: 1h 47min 36s
# Wall time: 53min 50s

# %%
fig = plt.figure(figsize=(20, 10))

for i, (train_log, val_log, params) in enumerate(learning_curves):
    
    grad_clipping, initializer, lr = params
    ax = plt.subplot(len(initializers) * 2, len(lrs), i+1) 
    display_learning_curve1(ax, train_log, val_log, initializer, lr)

# %% [markdown]
# For small network no noticeable improvemt is observed for any learning rate.
#
# Let's try a bigger network

# %% [markdown]
# ### Medium network

# %%
# %%time
layer_sizes = [200] * 4

lrs = [0.07, 0.1, 0.3, 0.5]
initializers = ['normal', 'xavier']
grad_clippings = [0, 5]

n_epochs = 50

learning_curves = []
logfile_path = 'logs/notebook_' + datetime.datetime.now().strftime('%Y%m%d') + '.log'
with open(logfile_path, 'a') as logfile:
    for params in itertools.product(grad_clippings, initializers, lrs):
        grad_clipping, initializer, lr = params
        train_log, val_log = build_and_train1(layer_sizes,
                                              initializer, lr, n_epochs, grad_clipping=grad_clipping, logfile=logfile)

        learning_curves.append((train_log, val_log, params))
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:5: RuntimeWarning: invalid value encountered in subtract
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:4: RuntimeWarning: invalid value encountered in subtract
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:13: RuntimeWarning: invalid value encountered in greater
# CPU times: user 5h 19min 12s, sys: 2h 19min 29s, total: 7h 38min 41s
# Wall time: 3h 50min 24s

# %%
fig = plt.figure(figsize=(20, 10))

for i, (train_log, val_log, params) in enumerate(learning_curves):
    
    grad_clipping, initializer, lr = params
    ax = plt.subplot(len(initializers) * 2, len(lrs), i+1) 
    display_learning_curve1(ax, train_log, val_log, initializer, lr)

# %% [markdown]
# For low learning rates networks learn faster and achieve a higher val accuracy when trained with Xavier initialization.
#
# For higher learning rates networks with 'normal' initialization simply do not learn at all, while networks with Xavier initialization exhibit very good perfomance (not considering network with highest learning rate where numerical overflow occured).
#
# Let's try even bigger network!

# %% [markdown]
# ### Large network

# %%
# %%time
layer_sizes = [200] * 6

lrs = [0.07, 0.1, 0.3, 0.5]
initializers = ['normal', 'xavier']
grad_clippings = [0, 5]

n_epochs = 50

learning_curves = []
logfile_path = 'logs/notebook_' + datetime.datetime.now().strftime('%Y%m%d') + '.log'
with open(logfile_path, 'a') as logfile:
    for params in itertools.product(grad_clippings, initializers, lrs):
        grad_clipping, initializer, lr = params
        train_log, val_log = build_and_train1(layer_sizes,
                                              initializer, lr, n_epochs, grad_clipping=grad_clipping, logfile=logfile)

        learning_curves.append((train_log, val_log, params))
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:13: RuntimeWarning: invalid value encountered in greater
# CPU times: user 7h 20min 50s, sys: 3h 36min 16s, total: 10h 57min 6s
# Wall time: 5h 30min 26s

# %%
fig = plt.figure(figsize=(20, 10))

for i, (train_log, val_log, params) in enumerate(learning_curves):
    
    grad_clipping, initializer, lr = params
    ax = plt.subplot(len(initializers) * 2, len(lrs), i+1) 
    display_learning_curve1(ax, train_log, val_log, initializer, lr)

# %% [markdown]
# For big networks the effect is even more pronounced: with 'normal' initialization networks do no learn at all for any learning rate, while networks with Xavier initialization show very good learning curves (last network again experienced numerical overflow)

# %% [markdown]
# #### Conclusion
#
# Xavier initialization allows networks learn faster and achieve higher accuracies compared to initialization with normal distrbution with fixed standard deviation (0.01 in our experiments). For large networks Xavier initialization even allows to succesfully train networks that do not learn at all with 'normal' initialization.

# %% [markdown]
# #### Option II: regularization

# %%
class Dense2(Layer):
    def __init__(self, input_units, output_units, initializer='xavier', learning_rate=0.1, alpha=0):
        """
        A dense layer is a layer which performs a learned affine transformation:
        f(x) = <W*x> + b
        """
        self.learning_rate = learning_rate
        self.alpha = alpha

        # initialize weights with small random numbers. 
        if initializer == 'normal':
            self.weights = np.random.randn(input_units, output_units) * 0.01
        elif initializer == 'xavier':
            self.weights = np.random.randn(input_units, output_units) * np.sqrt(2 / (input_units + output_units))
        else:
            raise ValueError('Wrong initializer parameter')
        self.biases = np.zeros(output_units)
        
    def forward(self,input):
        """
        Perform an affine transformation:
        f(x) = <W*x> + b
        
        input shape: [batch, input_units]
        output shape: [batch, output units]
        """
        return input.dot(self.weights) + self.biases
    
    def backward(self,input,grad_output):
        
        # compute d f / d x = d f / d dense * d dense / d x
        grad_input = grad_output.dot(self.weights.T)
        
        # compute gradient w.r.t. weights and biases
        grad_weights = input.T.dot(grad_output)
        grad_biases = np.sum(grad_output, axis=0)
        
        assert grad_weights.shape == self.weights.shape and grad_biases.shape == self.biases.shape
        
        # Here we perform a stochastic gradient descent step. 
        self.weights = self.weights - self.learning_rate * grad_weights - self.alpha * self.weights
        self.biases = self.biases - self.learning_rate * grad_biases
        
        return grad_input

# %%
def build_and_train2(layer_sizes, lr, alpha, n_epochs):
    
    print('\nTraining with and lr = {} and alpha = {} for n_epochs = {}'.format(lr, alpha, n_epochs))
    
    network = []
    network.append(Dense2(X_train.shape[1], layer_sizes[0], learning_rate=lr, alpha=alpha))
    network.append(ReLU())
    for layer in range(len(layer_sizes)-1):
        network.append(Dense2(layer_sizes[layer], layer_sizes[layer+1], learning_rate=lr, alpha=alpha))
        network.append(ReLU())
    network.append(Dense2(layer_sizes[-1], 10, learning_rate=lr, alpha=alpha))

    train_log = []
    val_log = []

    for epoch in range(n_epochs):

        for x_batch,y_batch in iterate_minibatches(X_train,y_train,batchsize=32,shuffle=True):
            train(network,x_batch,y_batch)

        train_log.append(np.mean(predict(network,X_train)==y_train))
        val_log.append(np.mean(predict(network,X_val)==y_val))    
        print('epoch = {:2d}, train acc = {:6.4f}, val acc = {:6.4f}'.format(epoch, train_log[-1], val_log[-1]))
        
    return train_log, val_log

def display_learning_curve2(ax, train_log, val_log, lr, alpha):
        
    ax.plot(train_log,label='train accuracy')
    ax.plot(val_log,label='val accuracy')
    ax.set_ylim(0.86, 1)
#     plt.legend(loc='best')
    ax.set_title('lr = {}, alpha = {}'.format(lr, alpha), fontsize=14)
    ax.text(0.3, 0.2, 'train acc = {:6.4f}\n   val acc = {:6.4f}'.format(train_log[-1], val_log[-1]),
            ha='left', va='bottom', fontsize=14, transform=ax.transAxes)
    ax.grid()

# %%
# %%time
layer_sizes = [100, 200]

lrs = [0.07, 0.1, 0.3, 0.5]
alphas = [3e-5, 7e-5, 1e-4]

n_epochs = 50


fig = plt.figure(figsize=(20, 10))
i = 0
for alpha, lr in itertools.product(alphas, lrs):
    i += 1
    train_log, val_log = build_and_train2(layer_sizes, lr, alpha, n_epochs)

    ax = plt.subplot(len(alphas), len(lrs), i) 
    display_learning_curve2(ax, train_log, val_log, lr, alpha)
# Out:
# Training with and lr = 0.07 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9487, val acc = 0.9510
# epoch =  1, train acc = 0.9593, val acc = 0.9565
# epoch =  2, train acc = 0.9719, val acc = 0.9659
# epoch =  3, train acc = 0.9780, val acc = 0.9699
# epoch =  4, train acc = 0.9830, val acc = 0.9725
# epoch =  5, train acc = 0.9847, val acc = 0.9716
# epoch =  6, train acc = 0.9883, val acc = 0.9759
# epoch =  7, train acc = 0.9890, val acc = 0.9749
# epoch =  8, train acc = 0.9918, val acc = 0.9765
# epoch =  9, train acc = 0.9895, val acc = 0.9749
# epoch = 10, train acc = 0.9926, val acc = 0.9753
# epoch = 11, train acc = 0.9933, val acc = 0.9764
# epoch = 12, train acc = 0.9944, val acc = 0.9781
# epoch = 13, train acc = 0.9950, val acc = 0.9785
# epoch = 14, train acc = 0.9953, val acc = 0.9786
# epoch = 15, train acc = 0.9968, val acc = 0.9787
# epoch = 16, train acc = 0.9956, val acc = 0.9782
# epoch = 17, train acc = 0.9971, val acc = 0.9795
# epoch = 18, train acc = 0.9946, val acc = 0.9770
# epoch = 19, train acc = 0.9963, val acc = 0.9779
# epoch = 20, train acc = 0.9975, val acc = 0.9792
# epoch = 21, train acc = 0.9977, val acc = 0.9794
# epoch = 22, train acc = 0.9968, val acc = 0.9796
# epoch = 23, train acc = 0.9966, val acc = 0.9783
# epoch = 24, train acc = 0.9969, val acc = 0.9783
# epoch = 25, train acc = 0.9982, val acc = 0.9781
# epoch = 26, train acc = 0.9986, val acc = 0.9796
# epoch = 27, train acc = 0.9966, val acc = 0.9781
# epoch = 28, train acc = 0.9983, val acc = 0.9798
# epoch = 29, train acc = 0.9980, val acc = 0.9806
# epoch = 30, train acc = 0.9984, val acc = 0.9784
# epoch = 31, train acc = 0.9952, val acc = 0.9764
# epoch = 32, train acc = 0.9976, val acc = 0.9790
# epoch = 33, train acc = 0.9974, val acc = 0.9793
# epoch = 34, train acc = 0.9986, val acc = 0.9801
# epoch = 35, train acc = 0.9986, val acc = 0.9793
# epoch = 36, train acc = 0.9973, val acc = 0.9796
# epoch = 37, train acc = 0.9988, val acc = 0.9800
# epoch = 38, train acc = 0.9986, val acc = 0.9804
# epoch = 39, train acc = 0.9960, val acc = 0.9763
# epoch = 40, train acc = 0.9988, val acc = 0.9814
# epoch = 41, train acc = 0.9980, val acc = 0.9778
# epoch = 42, train acc = 0.9988, val acc = 0.9797
# epoch = 43, train acc = 0.9968, val acc = 0.9783
# epoch = 44, train acc = 0.9988, val acc = 0.9790
# epoch = 45, train acc = 0.9985, val acc = 0.9810
# epoch = 46, train acc = 0.9989, val acc = 0.9806
# epoch = 47, train acc = 0.9992, val acc = 0.9812
# epoch = 48, train acc = 0.9989, val acc = 0.9786
# epoch = 49, train acc = 0.9990, val acc = 0.9811
#
# Training with and lr = 0.1 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9552, val acc = 0.9561
# epoch =  1, train acc = 0.9585, val acc = 0.9582
# epoch =  2, train acc = 0.9774, val acc = 0.9720
# epoch =  3, train acc = 0.9812, val acc = 0.9739
# epoch =  4, train acc = 0.9840, val acc = 0.9713
# epoch =  5, train acc = 0.9886, val acc = 0.9765
# epoch =  6, train acc = 0.9908, val acc = 0.9781
# epoch =  7, train acc = 0.9921, val acc = 0.9776
# epoch =  8, train acc = 0.9926, val acc = 0.9767
# epoch =  9, train acc = 0.9937, val acc = 0.9783
# epoch = 10, train acc = 0.9936, val acc = 0.9777
# epoch = 11, train acc = 0.9965, val acc = 0.9797
# epoch = 12, train acc = 0.9953, val acc = 0.9772
# epoch = 13, train acc = 0.9961, val acc = 0.9809
# epoch = 14, train acc = 0.9935, val acc = 0.9765
# epoch = 15, train acc = 0.9981, val acc = 0.9816
# epoch = 16, train acc = 0.9974, val acc = 0.9807
# epoch = 17, train acc = 0.9957, val acc = 0.9764
# epoch = 18, train acc = 0.9975, val acc = 0.9810
# epoch = 19, train acc = 0.9986, val acc = 0.9810
# epoch = 20, train acc = 0.9982, val acc = 0.9803
# epoch = 21, train acc = 0.9970, val acc = 0.9786
# epoch = 22, train acc = 0.9980, val acc = 0.9782
# epoch = 23, train acc = 0.9982, val acc = 0.9784
# epoch = 24, train acc = 0.9979, val acc = 0.9800
# epoch = 25, train acc = 0.9995, val acc = 0.9815
# epoch = 26, train acc = 0.9938, val acc = 0.9767
# epoch = 27, train acc = 0.9988, val acc = 0.9810
# epoch = 28, train acc = 0.9974, val acc = 0.9795
# epoch = 29, train acc = 0.9993, val acc = 0.9816
# epoch = 30, train acc = 0.9953, val acc = 0.9764
# epoch = 31, train acc = 0.9987, val acc = 0.9801
# epoch = 32, train acc = 0.9992, val acc = 0.9803
# epoch = 33, train acc = 0.9990, val acc = 0.9797
# epoch = 34, train acc = 0.9984, val acc = 0.9798
# epoch = 35, train acc = 0.9988, val acc = 0.9811
# epoch = 36, train acc = 0.9994, val acc = 0.9815
# epoch = 37, train acc = 0.9991, val acc = 0.9804
# epoch = 38, train acc = 0.9976, val acc = 0.9793
# epoch = 39, train acc = 0.9985, val acc = 0.9798
# epoch = 40, train acc = 0.9988, val acc = 0.9801
# epoch = 41, train acc = 0.9992, val acc = 0.9812
# epoch = 42, train acc = 0.9962, val acc = 0.9785
# epoch = 43, train acc = 0.9985, val acc = 0.9802
# epoch = 44, train acc = 0.9986, val acc = 0.9807
# epoch = 45, train acc = 0.9992, val acc = 0.9812
# epoch = 46, train acc = 0.9993, val acc = 0.9812
# epoch = 47, train acc = 0.9990, val acc = 0.9806
# epoch = 48, train acc = 0.9993, val acc = 0.9795
# epoch = 49, train acc = 0.9990, val acc = 0.9801
#
# Training with and lr = 0.3 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9642, val acc = 0.9623
# epoch =  1, train acc = 0.9679, val acc = 0.9634
# epoch =  2, train acc = 0.9781, val acc = 0.9672
# epoch =  3, train acc = 0.9845, val acc = 0.9742
# epoch =  4, train acc = 0.9753, val acc = 0.9612
# epoch =  5, train acc = 0.9901, val acc = 0.9775
# epoch =  6, train acc = 0.9861, val acc = 0.9726
# epoch =  7, train acc = 0.9920, val acc = 0.9764
# epoch =  8, train acc = 0.9921, val acc = 0.9732
# epoch =  9, train acc = 0.9924, val acc = 0.9753
# epoch = 10, train acc = 0.9939, val acc = 0.9740
# epoch = 11, train acc = 0.9938, val acc = 0.9761
# epoch = 12, train acc = 0.9955, val acc = 0.9782
# epoch = 13, train acc = 0.9955, val acc = 0.9776
# epoch = 14, train acc = 0.9975, val acc = 0.9788
# epoch = 15, train acc = 0.9941, val acc = 0.9756
# epoch = 16, train acc = 0.9954, val acc = 0.9759
# epoch = 17, train acc = 0.9953, val acc = 0.9729
# epoch = 18, train acc = 0.9928, val acc = 0.9730
# epoch = 19, train acc = 0.9980, val acc = 0.9783
# epoch = 20, train acc = 0.9952, val acc = 0.9763
# epoch = 21, train acc = 0.9970, val acc = 0.9787
# epoch = 22, train acc = 0.9965, val acc = 0.9776
# epoch = 23, train acc = 0.9938, val acc = 0.9752
# epoch = 24, train acc = 0.9958, val acc = 0.9785
# epoch = 25, train acc = 0.9983, val acc = 0.9788
# epoch = 26, train acc = 0.9982, val acc = 0.9802
# epoch = 27, train acc = 0.9928, val acc = 0.9765
# epoch = 28, train acc = 0.9800, val acc = 0.9617
# epoch = 29, train acc = 0.9986, val acc = 0.9815
# epoch = 30, train acc = 0.9966, val acc = 0.9779
# epoch = 31, train acc = 0.9988, val acc = 0.9789
# epoch = 32, train acc = 0.9976, val acc = 0.9794
# epoch = 33, train acc = 0.9987, val acc = 0.9795
# epoch = 34, train acc = 0.9957, val acc = 0.9764
# epoch = 35, train acc = 0.9996, val acc = 0.9811
# epoch = 36, train acc = 1.0000, val acc = 0.9818
# epoch = 37, train acc = 0.9999, val acc = 0.9813
# epoch = 38, train acc = 1.0000, val acc = 0.9811
# epoch = 39, train acc = 0.9983, val acc = 0.9785
# epoch = 40, train acc = 0.9919, val acc = 0.9755
# epoch = 41, train acc = 0.9937, val acc = 0.9783
# epoch = 42, train acc = 0.9939, val acc = 0.9778
# epoch = 43, train acc = 0.9953, val acc = 0.9773
# epoch = 44, train acc = 0.9964, val acc = 0.9790
# epoch = 45, train acc = 0.9969, val acc = 0.9795
# epoch = 46, train acc = 0.9942, val acc = 0.9760
# epoch = 47, train acc = 0.9983, val acc = 0.9802
# epoch = 48, train acc = 0.9991, val acc = 0.9819
# epoch = 49, train acc = 0.9996, val acc = 0.9817
#
# Training with and lr = 0.5 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9492, val acc = 0.9491
# epoch =  1, train acc = 0.9721, val acc = 0.9661
# epoch =  2, train acc = 0.9779, val acc = 0.9691
# epoch =  3, train acc = 0.9813, val acc = 0.9729
# epoch =  4, train acc = 0.9854, val acc = 0.9742
# epoch =  5, train acc = 0.9846, val acc = 0.9731
# epoch =  6, train acc = 0.9870, val acc = 0.9713
# epoch =  7, train acc = 0.9880, val acc = 0.9716
# epoch =  8, train acc = 0.9824, val acc = 0.9682
# epoch =  9, train acc = 0.9929, val acc = 0.9756
# epoch = 10, train acc = 0.9818, val acc = 0.9669
# epoch = 11, train acc = 0.9903, val acc = 0.9742
# epoch = 12, train acc = 0.9930, val acc = 0.9770
# epoch = 13, train acc = 0.9932, val acc = 0.9720
# epoch = 14, train acc = 0.9910, val acc = 0.9731
# epoch = 15, train acc = 0.9946, val acc = 0.9733
# epoch = 16, train acc = 0.9905, val acc = 0.9709
# epoch = 17, train acc = 0.9953, val acc = 0.9752
# epoch = 18, train acc = 0.9967, val acc = 0.9780
# epoch = 19, train acc = 0.9939, val acc = 0.9758
# epoch = 20, train acc = 0.9940, val acc = 0.9754
# epoch = 21, train acc = 0.9925, val acc = 0.9766
# epoch = 22, train acc = 0.9970, val acc = 0.9761
# epoch = 23, train acc = 0.9925, val acc = 0.9728
# epoch = 24, train acc = 0.9759, val acc = 0.9590
# epoch = 25, train acc = 0.9857, val acc = 0.9688
# epoch = 26, train acc = 0.9943, val acc = 0.9759
# epoch = 27, train acc = 0.9763, val acc = 0.9634
# epoch = 28, train acc = 0.9916, val acc = 0.9748
# epoch = 29, train acc = 0.9956, val acc = 0.9787
# epoch = 30, train acc = 0.9945, val acc = 0.9757
# epoch = 31, train acc = 0.9971, val acc = 0.9785
# epoch = 32, train acc = 0.9917, val acc = 0.9736
# epoch = 33, train acc = 0.9949, val acc = 0.9766
# epoch = 34, train acc = 0.9972, val acc = 0.9784
# epoch = 35, train acc = 0.9974, val acc = 0.9797
# epoch = 36, train acc = 0.9954, val acc = 0.9785
# epoch = 37, train acc = 0.9938, val acc = 0.9750
# epoch = 38, train acc = 0.9897, val acc = 0.9702
# epoch = 39, train acc = 0.9927, val acc = 0.9741
# epoch = 40, train acc = 0.9976, val acc = 0.9779
# epoch = 41, train acc = 0.9949, val acc = 0.9770
# epoch = 42, train acc = 0.9934, val acc = 0.9741
# epoch = 43, train acc = 0.9961, val acc = 0.9804
# epoch = 44, train acc = 0.9947, val acc = 0.9752
# epoch = 45, train acc = 0.9950, val acc = 0.9754
# epoch = 46, train acc = 0.9945, val acc = 0.9743
# epoch = 47, train acc = 0.9971, val acc = 0.9783
# epoch = 48, train acc = 0.9961, val acc = 0.9788
# epoch = 49, train acc = 0.9941, val acc = 0.9748
#
# Training with and lr = 0.07 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9443, val acc = 0.9483
# epoch =  1, train acc = 0.9625, val acc = 0.9610
# epoch =  2, train acc = 0.9720, val acc = 0.9673
# epoch =  3, train acc = 0.9742, val acc = 0.9694
# epoch =  4, train acc = 0.9794, val acc = 0.9717
# epoch =  5, train acc = 0.9820, val acc = 0.9744
# epoch =  6, train acc = 0.9824, val acc = 0.9738
# epoch =  7, train acc = 0.9858, val acc = 0.9759
# epoch =  8, train acc = 0.9843, val acc = 0.9738
# epoch =  9, train acc = 0.9871, val acc = 0.9763
# epoch = 10, train acc = 0.9795, val acc = 0.9702
# epoch = 11, train acc = 0.9896, val acc = 0.9789
# epoch = 12, train acc = 0.9894, val acc = 0.9772
# epoch = 13, train acc = 0.9875, val acc = 0.9772
# epoch = 14, train acc = 0.9915, val acc = 0.9789
# epoch = 15, train acc = 0.9893, val acc = 0.9762
# epoch = 16, train acc = 0.9900, val acc = 0.9777
# epoch = 17, train acc = 0.9926, val acc = 0.9801
# epoch = 18, train acc = 0.9906, val acc = 0.9769
# epoch = 19, train acc = 0.9931, val acc = 0.9804
# epoch = 20, train acc = 0.9786, val acc = 0.9680
# epoch = 21, train acc = 0.9898, val acc = 0.9760
# epoch = 22, train acc = 0.9913, val acc = 0.9776
# epoch = 23, train acc = 0.9915, val acc = 0.9789
# epoch = 24, train acc = 0.9926, val acc = 0.9782
# epoch = 25, train acc = 0.9906, val acc = 0.9781
# epoch = 26, train acc = 0.9933, val acc = 0.9780
# epoch = 27, train acc = 0.9935, val acc = 0.9786
# epoch = 28, train acc = 0.9925, val acc = 0.9799
# epoch = 29, train acc = 0.9920, val acc = 0.9778
# epoch = 30, train acc = 0.9918, val acc = 0.9768
# epoch = 31, train acc = 0.9926, val acc = 0.9801
# epoch = 32, train acc = 0.9950, val acc = 0.9802
# epoch = 33, train acc = 0.9914, val acc = 0.9767
# epoch = 34, train acc = 0.9933, val acc = 0.9798
# epoch = 35, train acc = 0.9935, val acc = 0.9786
# epoch = 36, train acc = 0.9914, val acc = 0.9765
# epoch = 37, train acc = 0.9939, val acc = 0.9810
# epoch = 38, train acc = 0.9929, val acc = 0.9782
# epoch = 39, train acc = 0.9953, val acc = 0.9796
# epoch = 40, train acc = 0.9935, val acc = 0.9803
# epoch = 41, train acc = 0.9953, val acc = 0.9805
# epoch = 42, train acc = 0.9921, val acc = 0.9771
# epoch = 43, train acc = 0.9935, val acc = 0.9795
# epoch = 44, train acc = 0.9930, val acc = 0.9791
# epoch = 45, train acc = 0.9931, val acc = 0.9796
# epoch = 46, train acc = 0.9945, val acc = 0.9811
# epoch = 47, train acc = 0.9940, val acc = 0.9804
# epoch = 48, train acc = 0.9921, val acc = 0.9774
# epoch = 49, train acc = 0.9931, val acc = 0.9781
#
# Training with and lr = 0.1 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9547, val acc = 0.9567
# epoch =  1, train acc = 0.9657, val acc = 0.9635
# epoch =  2, train acc = 0.9765, val acc = 0.9704
# epoch =  3, train acc = 0.9784, val acc = 0.9707
# epoch =  4, train acc = 0.9837, val acc = 0.9763
# epoch =  5, train acc = 0.9864, val acc = 0.9762
# epoch =  6, train acc = 0.9799, val acc = 0.9730
# epoch =  7, train acc = 0.9863, val acc = 0.9741
# epoch =  8, train acc = 0.9838, val acc = 0.9723
# epoch =  9, train acc = 0.9882, val acc = 0.9746
# epoch = 10, train acc = 0.9902, val acc = 0.9779
# epoch = 11, train acc = 0.9910, val acc = 0.9779
# epoch = 12, train acc = 0.9890, val acc = 0.9742
# epoch = 13, train acc = 0.9918, val acc = 0.9771
# epoch = 14, train acc = 0.9909, val acc = 0.9773
# epoch = 15, train acc = 0.9895, val acc = 0.9753
# epoch = 16, train acc = 0.9921, val acc = 0.9784
# epoch = 17, train acc = 0.9910, val acc = 0.9758
# epoch = 18, train acc = 0.9936, val acc = 0.9792
# epoch = 19, train acc = 0.9923, val acc = 0.9770
# epoch = 20, train acc = 0.9925, val acc = 0.9780
# epoch = 21, train acc = 0.9916, val acc = 0.9755
# epoch = 22, train acc = 0.9929, val acc = 0.9773
# epoch = 23, train acc = 0.9913, val acc = 0.9765
# epoch = 24, train acc = 0.9930, val acc = 0.9770
# epoch = 25, train acc = 0.9941, val acc = 0.9800
# epoch = 26, train acc = 0.9920, val acc = 0.9767
# epoch = 27, train acc = 0.9941, val acc = 0.9777
# epoch = 28, train acc = 0.9931, val acc = 0.9777
# epoch = 29, train acc = 0.9957, val acc = 0.9797
# epoch = 30, train acc = 0.9931, val acc = 0.9769
# epoch = 31, train acc = 0.9951, val acc = 0.9794
# epoch = 32, train acc = 0.9943, val acc = 0.9780
# epoch = 33, train acc = 0.9925, val acc = 0.9759
# epoch = 34, train acc = 0.9918, val acc = 0.9771
# epoch = 35, train acc = 0.9942, val acc = 0.9780
# epoch = 36, train acc = 0.9932, val acc = 0.9767
# epoch = 37, train acc = 0.9940, val acc = 0.9799
# epoch = 38, train acc = 0.9892, val acc = 0.9754
# epoch = 39, train acc = 0.9960, val acc = 0.9812
# epoch = 40, train acc = 0.9956, val acc = 0.9808
# epoch = 41, train acc = 0.9932, val acc = 0.9775
# epoch = 42, train acc = 0.9934, val acc = 0.9777
# epoch = 43, train acc = 0.9918, val acc = 0.9755
# epoch = 44, train acc = 0.9927, val acc = 0.9775
# epoch = 45, train acc = 0.9964, val acc = 0.9801
# epoch = 46, train acc = 0.9933, val acc = 0.9773
# epoch = 47, train acc = 0.9945, val acc = 0.9796
# epoch = 48, train acc = 0.9962, val acc = 0.9806
# epoch = 49, train acc = 0.9936, val acc = 0.9790
#
# Training with and lr = 0.3 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9652, val acc = 0.9645
# epoch =  1, train acc = 0.9663, val acc = 0.9615
# epoch =  2, train acc = 0.9812, val acc = 0.9719
# epoch =  3, train acc = 0.9859, val acc = 0.9730
# epoch =  4, train acc = 0.9849, val acc = 0.9723
# epoch =  5, train acc = 0.9881, val acc = 0.9732
# epoch =  6, train acc = 0.9907, val acc = 0.9768
# epoch =  7, train acc = 0.9881, val acc = 0.9739
# epoch =  8, train acc = 0.9896, val acc = 0.9745
# epoch =  9, train acc = 0.9897, val acc = 0.9752
# epoch = 10, train acc = 0.9901, val acc = 0.9736
# epoch = 11, train acc = 0.9946, val acc = 0.9781
# epoch = 12, train acc = 0.9874, val acc = 0.9714
# epoch = 13, train acc = 0.9934, val acc = 0.9769
# epoch = 14, train acc = 0.9906, val acc = 0.9743
# epoch = 15, train acc = 0.9924, val acc = 0.9770
# epoch = 16, train acc = 0.9936, val acc = 0.9772
# epoch = 17, train acc = 0.9812, val acc = 0.9697
# epoch = 18, train acc = 0.9926, val acc = 0.9786
# epoch = 19, train acc = 0.9831, val acc = 0.9686
# epoch = 20, train acc = 0.9893, val acc = 0.9731
# epoch = 21, train acc = 0.9935, val acc = 0.9768
# epoch = 22, train acc = 0.9923, val acc = 0.9782
# epoch = 23, train acc = 0.9944, val acc = 0.9764
# epoch = 24, train acc = 0.9935, val acc = 0.9793
# epoch = 25, train acc = 0.9942, val acc = 0.9798
# epoch = 26, train acc = 0.9892, val acc = 0.9762
# epoch = 27, train acc = 0.9927, val acc = 0.9778
# epoch = 28, train acc = 0.9927, val acc = 0.9778
# epoch = 29, train acc = 0.9929, val acc = 0.9753
# epoch = 30, train acc = 0.9900, val acc = 0.9762
# epoch = 31, train acc = 0.9919, val acc = 0.9779
# epoch = 32, train acc = 0.9924, val acc = 0.9739
# epoch = 33, train acc = 0.9911, val acc = 0.9741
# epoch = 34, train acc = 0.9913, val acc = 0.9771
# epoch = 35, train acc = 0.9942, val acc = 0.9786
# epoch = 36, train acc = 0.9954, val acc = 0.9804
# epoch = 37, train acc = 0.9875, val acc = 0.9718
# epoch = 38, train acc = 0.9926, val acc = 0.9772
# epoch = 39, train acc = 0.9935, val acc = 0.9777
# epoch = 40, train acc = 0.9851, val acc = 0.9710
# epoch = 41, train acc = 0.9945, val acc = 0.9789
# epoch = 42, train acc = 0.9918, val acc = 0.9753
# epoch = 43, train acc = 0.9922, val acc = 0.9764
# epoch = 44, train acc = 0.9908, val acc = 0.9739
# epoch = 45, train acc = 0.9932, val acc = 0.9768
# epoch = 46, train acc = 0.9953, val acc = 0.9802
# epoch = 47, train acc = 0.9891, val acc = 0.9748
# epoch = 48, train acc = 0.9893, val acc = 0.9703
# epoch = 49, train acc = 0.9802, val acc = 0.9653
#
# Training with and lr = 0.5 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9598, val acc = 0.9551
# epoch =  1, train acc = 0.9710, val acc = 0.9657
# epoch =  2, train acc = 0.9720, val acc = 0.9642
# epoch =  3, train acc = 0.9812, val acc = 0.9709
# epoch =  4, train acc = 0.9776, val acc = 0.9643
# epoch =  5, train acc = 0.9817, val acc = 0.9667
# epoch =  6, train acc = 0.9812, val acc = 0.9675
# epoch =  7, train acc = 0.9835, val acc = 0.9705
# epoch =  8, train acc = 0.9828, val acc = 0.9702
# epoch =  9, train acc = 0.9858, val acc = 0.9712
# epoch = 10, train acc = 0.9900, val acc = 0.9749
# epoch = 11, train acc = 0.9826, val acc = 0.9676
# epoch = 12, train acc = 0.9854, val acc = 0.9674
# epoch = 13, train acc = 0.9787, val acc = 0.9641
# epoch = 14, train acc = 0.9842, val acc = 0.9689
# epoch = 15, train acc = 0.9861, val acc = 0.9727
# epoch = 16, train acc = 0.9878, val acc = 0.9741
# epoch = 17, train acc = 0.9905, val acc = 0.9751
# epoch = 18, train acc = 0.9903, val acc = 0.9723
# epoch = 19, train acc = 0.9891, val acc = 0.9750
# epoch = 20, train acc = 0.9920, val acc = 0.9765
# epoch = 21, train acc = 0.9860, val acc = 0.9716
# epoch = 22, train acc = 0.9875, val acc = 0.9729
# epoch = 23, train acc = 0.9902, val acc = 0.9729
# epoch = 24, train acc = 0.9923, val acc = 0.9746
# epoch = 25, train acc = 0.9911, val acc = 0.9742
# epoch = 26, train acc = 0.9879, val acc = 0.9727
# epoch = 27, train acc = 0.9898, val acc = 0.9732
# epoch = 28, train acc = 0.9912, val acc = 0.9773
# epoch = 29, train acc = 0.9915, val acc = 0.9758
# epoch = 30, train acc = 0.9919, val acc = 0.9779
# epoch = 31, train acc = 0.9878, val acc = 0.9733
# epoch = 32, train acc = 0.9721, val acc = 0.9591
# epoch = 33, train acc = 0.9912, val acc = 0.9774
# epoch = 34, train acc = 0.9909, val acc = 0.9747
# epoch = 35, train acc = 0.9887, val acc = 0.9756
# epoch = 36, train acc = 0.9865, val acc = 0.9687
# epoch = 37, train acc = 0.9873, val acc = 0.9713
# epoch = 38, train acc = 0.9922, val acc = 0.9777
# epoch = 39, train acc = 0.9882, val acc = 0.9737
# epoch = 40, train acc = 0.9886, val acc = 0.9740
# epoch = 41, train acc = 0.9928, val acc = 0.9779
# epoch = 42, train acc = 0.9894, val acc = 0.9719
# epoch = 43, train acc = 0.9813, val acc = 0.9659
# epoch = 44, train acc = 0.9895, val acc = 0.9747
# epoch = 45, train acc = 0.9941, val acc = 0.9779
# epoch = 46, train acc = 0.9869, val acc = 0.9710
# epoch = 47, train acc = 0.9859, val acc = 0.9709
# epoch = 48, train acc = 0.9888, val acc = 0.9715
# epoch = 49, train acc = 0.9883, val acc = 0.9740
#
# Training with and lr = 0.07 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9479, val acc = 0.9522
# epoch =  1, train acc = 0.9610, val acc = 0.9622
# epoch =  2, train acc = 0.9687, val acc = 0.9647
# epoch =  3, train acc = 0.9751, val acc = 0.9718
# epoch =  4, train acc = 0.9799, val acc = 0.9733
# epoch =  5, train acc = 0.9808, val acc = 0.9742
# epoch =  6, train acc = 0.9809, val acc = 0.9750
# epoch =  7, train acc = 0.9797, val acc = 0.9736
# epoch =  8, train acc = 0.9795, val acc = 0.9719
# epoch =  9, train acc = 0.9834, val acc = 0.9750
# epoch = 10, train acc = 0.9857, val acc = 0.9758
# epoch = 11, train acc = 0.9871, val acc = 0.9775
# epoch = 12, train acc = 0.9838, val acc = 0.9735
# epoch = 13, train acc = 0.9841, val acc = 0.9736
# epoch = 14, train acc = 0.9880, val acc = 0.9768
# epoch = 15, train acc = 0.9860, val acc = 0.9743
# epoch = 16, train acc = 0.9875, val acc = 0.9765
# epoch = 17, train acc = 0.9858, val acc = 0.9748
# epoch = 18, train acc = 0.9880, val acc = 0.9753
# epoch = 19, train acc = 0.9881, val acc = 0.9774
# epoch = 20, train acc = 0.9886, val acc = 0.9767
# epoch = 21, train acc = 0.9893, val acc = 0.9793
# epoch = 22, train acc = 0.9868, val acc = 0.9763
# epoch = 23, train acc = 0.9899, val acc = 0.9770
# epoch = 24, train acc = 0.9881, val acc = 0.9756
# epoch = 25, train acc = 0.9881, val acc = 0.9767
# epoch = 26, train acc = 0.9833, val acc = 0.9721
# epoch = 27, train acc = 0.9890, val acc = 0.9779
# epoch = 28, train acc = 0.9849, val acc = 0.9743
# epoch = 29, train acc = 0.9879, val acc = 0.9766
# epoch = 30, train acc = 0.9886, val acc = 0.9762
# epoch = 31, train acc = 0.9880, val acc = 0.9754
# epoch = 32, train acc = 0.9872, val acc = 0.9750
# epoch = 33, train acc = 0.9879, val acc = 0.9765
# epoch = 34, train acc = 0.9884, val acc = 0.9755
# epoch = 35, train acc = 0.9891, val acc = 0.9781
# epoch = 36, train acc = 0.9896, val acc = 0.9781
# epoch = 37, train acc = 0.9901, val acc = 0.9787
# epoch = 38, train acc = 0.9867, val acc = 0.9741
# epoch = 39, train acc = 0.9886, val acc = 0.9778
# epoch = 40, train acc = 0.9893, val acc = 0.9779
# epoch = 41, train acc = 0.9882, val acc = 0.9761
# epoch = 42, train acc = 0.9902, val acc = 0.9783
# epoch = 43, train acc = 0.9890, val acc = 0.9764
# epoch = 44, train acc = 0.9877, val acc = 0.9768
# epoch = 45, train acc = 0.9888, val acc = 0.9768
# epoch = 46, train acc = 0.9854, val acc = 0.9745
# epoch = 47, train acc = 0.9877, val acc = 0.9762
# epoch = 48, train acc = 0.9901, val acc = 0.9784
# epoch = 49, train acc = 0.9912, val acc = 0.9790
#
# Training with and lr = 0.1 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9535, val acc = 0.9557
# epoch =  1, train acc = 0.9679, val acc = 0.9679
# epoch =  2, train acc = 0.9761, val acc = 0.9719
# epoch =  3, train acc = 0.9791, val acc = 0.9724
# epoch =  4, train acc = 0.9827, val acc = 0.9755
# epoch =  5, train acc = 0.9831, val acc = 0.9733
# epoch =  6, train acc = 0.9829, val acc = 0.9739
# epoch =  7, train acc = 0.9854, val acc = 0.9750
# epoch =  8, train acc = 0.9876, val acc = 0.9773
# epoch =  9, train acc = 0.9859, val acc = 0.9750
# epoch = 10, train acc = 0.9879, val acc = 0.9757
# epoch = 11, train acc = 0.9898, val acc = 0.9786
# epoch = 12, train acc = 0.9905, val acc = 0.9783
# epoch = 13, train acc = 0.9897, val acc = 0.9769
# epoch = 14, train acc = 0.9894, val acc = 0.9778
# epoch = 15, train acc = 0.9900, val acc = 0.9779
# epoch = 16, train acc = 0.9891, val acc = 0.9764
# epoch = 17, train acc = 0.9895, val acc = 0.9783
# epoch = 18, train acc = 0.9874, val acc = 0.9741
# epoch = 19, train acc = 0.9907, val acc = 0.9780
# epoch = 20, train acc = 0.9918, val acc = 0.9783
# epoch = 21, train acc = 0.9926, val acc = 0.9812
# epoch = 22, train acc = 0.9924, val acc = 0.9773
# epoch = 23, train acc = 0.9906, val acc = 0.9782
# epoch = 24, train acc = 0.9898, val acc = 0.9758
# epoch = 25, train acc = 0.9892, val acc = 0.9748
# epoch = 26, train acc = 0.9920, val acc = 0.9786
# epoch = 27, train acc = 0.9928, val acc = 0.9791
# epoch = 28, train acc = 0.9898, val acc = 0.9764
# epoch = 29, train acc = 0.9899, val acc = 0.9767
# epoch = 30, train acc = 0.9916, val acc = 0.9780
# epoch = 31, train acc = 0.9926, val acc = 0.9798
# epoch = 32, train acc = 0.9914, val acc = 0.9786
# epoch = 33, train acc = 0.9899, val acc = 0.9757
# epoch = 34, train acc = 0.9892, val acc = 0.9774
# epoch = 35, train acc = 0.9890, val acc = 0.9766
# epoch = 36, train acc = 0.9890, val acc = 0.9759
# epoch = 37, train acc = 0.9907, val acc = 0.9780
# epoch = 38, train acc = 0.9901, val acc = 0.9785
# epoch = 39, train acc = 0.9928, val acc = 0.9801
# epoch = 40, train acc = 0.9905, val acc = 0.9769
# epoch = 41, train acc = 0.9937, val acc = 0.9805
# epoch = 42, train acc = 0.9924, val acc = 0.9775
# epoch = 43, train acc = 0.9928, val acc = 0.9793
# epoch = 44, train acc = 0.9898, val acc = 0.9765
# epoch = 45, train acc = 0.9926, val acc = 0.9805
# epoch = 46, train acc = 0.9852, val acc = 0.9742
# epoch = 47, train acc = 0.9897, val acc = 0.9766
# epoch = 48, train acc = 0.9901, val acc = 0.9792
# epoch = 49, train acc = 0.9936, val acc = 0.9807
#
# Training with and lr = 0.3 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9606, val acc = 0.9577
# epoch =  1, train acc = 0.9760, val acc = 0.9704
# epoch =  2, train acc = 0.9716, val acc = 0.9611
# epoch =  3, train acc = 0.9814, val acc = 0.9687
# epoch =  4, train acc = 0.9839, val acc = 0.9708
# epoch =  5, train acc = 0.9882, val acc = 0.9762
# epoch =  6, train acc = 0.9909, val acc = 0.9764
# epoch =  7, train acc = 0.9883, val acc = 0.9754
# epoch =  8, train acc = 0.9783, val acc = 0.9660
# epoch =  9, train acc = 0.9889, val acc = 0.9748
# epoch = 10, train acc = 0.9881, val acc = 0.9767
# epoch = 11, train acc = 0.9900, val acc = 0.9777
# epoch = 12, train acc = 0.9919, val acc = 0.9803
# epoch = 13, train acc = 0.9917, val acc = 0.9751
# epoch = 14, train acc = 0.9873, val acc = 0.9733
# epoch = 15, train acc = 0.9907, val acc = 0.9763
# epoch = 16, train acc = 0.9892, val acc = 0.9747
# epoch = 17, train acc = 0.9888, val acc = 0.9749
# epoch = 18, train acc = 0.9904, val acc = 0.9762
# epoch = 19, train acc = 0.9897, val acc = 0.9757
# epoch = 20, train acc = 0.9892, val acc = 0.9771
# epoch = 21, train acc = 0.9885, val acc = 0.9736
# epoch = 22, train acc = 0.9934, val acc = 0.9777
# epoch = 23, train acc = 0.9910, val acc = 0.9760
# epoch = 24, train acc = 0.9796, val acc = 0.9654
# epoch = 25, train acc = 0.9934, val acc = 0.9793
# epoch = 26, train acc = 0.9923, val acc = 0.9770
# epoch = 27, train acc = 0.9744, val acc = 0.9623
# epoch = 28, train acc = 0.9903, val acc = 0.9769
# epoch = 29, train acc = 0.9937, val acc = 0.9792
# epoch = 30, train acc = 0.9855, val acc = 0.9732
# epoch = 31, train acc = 0.9912, val acc = 0.9747
# epoch = 32, train acc = 0.9877, val acc = 0.9709
# epoch = 33, train acc = 0.9798, val acc = 0.9662
# epoch = 34, train acc = 0.9909, val acc = 0.9762
# epoch = 35, train acc = 0.9885, val acc = 0.9726
# epoch = 36, train acc = 0.9920, val acc = 0.9781
# epoch = 37, train acc = 0.9864, val acc = 0.9722
# epoch = 38, train acc = 0.9937, val acc = 0.9785
# epoch = 39, train acc = 0.9932, val acc = 0.9796
# epoch = 40, train acc = 0.9881, val acc = 0.9764
# epoch = 41, train acc = 0.9876, val acc = 0.9697
# epoch = 42, train acc = 0.9797, val acc = 0.9679
# epoch = 43, train acc = 0.9915, val acc = 0.9769
# epoch = 44, train acc = 0.9865, val acc = 0.9706
# epoch = 45, train acc = 0.9914, val acc = 0.9769
# epoch = 46, train acc = 0.9893, val acc = 0.9744
# epoch = 47, train acc = 0.9913, val acc = 0.9765
# epoch = 48, train acc = 0.9892, val acc = 0.9749
# epoch = 49, train acc = 0.9954, val acc = 0.9787
#
# Training with and lr = 0.5 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9601, val acc = 0.9579
# epoch =  1, train acc = 0.9675, val acc = 0.9619
# epoch =  2, train acc = 0.9791, val acc = 0.9716
# epoch =  3, train acc = 0.9779, val acc = 0.9686
# epoch =  4, train acc = 0.9807, val acc = 0.9724
# epoch =  5, train acc = 0.9811, val acc = 0.9701
# epoch =  6, train acc = 0.9751, val acc = 0.9631
# epoch =  7, train acc = 0.9841, val acc = 0.9728
# epoch =  8, train acc = 0.9825, val acc = 0.9697
# epoch =  9, train acc = 0.9856, val acc = 0.9737
# epoch = 10, train acc = 0.9849, val acc = 0.9727
# epoch = 11, train acc = 0.9881, val acc = 0.9744
# epoch = 12, train acc = 0.9861, val acc = 0.9716
# epoch = 13, train acc = 0.9826, val acc = 0.9687
# epoch = 14, train acc = 0.9801, val acc = 0.9682
# epoch = 15, train acc = 0.9837, val acc = 0.9686
# epoch = 16, train acc = 0.9888, val acc = 0.9757
# epoch = 17, train acc = 0.9840, val acc = 0.9707
# epoch = 18, train acc = 0.9871, val acc = 0.9754
# epoch = 19, train acc = 0.9789, val acc = 0.9650
# epoch = 20, train acc = 0.9844, val acc = 0.9719
# epoch = 21, train acc = 0.9903, val acc = 0.9768
# epoch = 22, train acc = 0.9873, val acc = 0.9727
# epoch = 23, train acc = 0.9688, val acc = 0.9578
# epoch = 24, train acc = 0.9838, val acc = 0.9693
# epoch = 25, train acc = 0.9875, val acc = 0.9740
# epoch = 26, train acc = 0.9843, val acc = 0.9733
# epoch = 27, train acc = 0.9820, val acc = 0.9711
# epoch = 28, train acc = 0.9856, val acc = 0.9733
# epoch = 29, train acc = 0.9896, val acc = 0.9762
# epoch = 30, train acc = 0.9861, val acc = 0.9742
# epoch = 31, train acc = 0.9870, val acc = 0.9709
# epoch = 32, train acc = 0.9901, val acc = 0.9782
# epoch = 33, train acc = 0.9897, val acc = 0.9783
# epoch = 34, train acc = 0.9925, val acc = 0.9796
# epoch = 35, train acc = 0.9820, val acc = 0.9694
# epoch = 36, train acc = 0.9836, val acc = 0.9689
# epoch = 37, train acc = 0.9876, val acc = 0.9735
# epoch = 38, train acc = 0.9823, val acc = 0.9692
# epoch = 39, train acc = 0.9863, val acc = 0.9731
# epoch = 40, train acc = 0.9893, val acc = 0.9785
# epoch = 41, train acc = 0.9867, val acc = 0.9713
# epoch = 42, train acc = 0.9890, val acc = 0.9753
# epoch = 43, train acc = 0.9784, val acc = 0.9629
# epoch = 44, train acc = 0.9913, val acc = 0.9768
# epoch = 45, train acc = 0.9850, val acc = 0.9722
# epoch = 46, train acc = 0.9909, val acc = 0.9755
# epoch = 47, train acc = 0.9913, val acc = 0.9782
# epoch = 48, train acc = 0.9894, val acc = 0.9760
# epoch = 49, train acc = 0.9897, val acc = 0.9739
# CPU times: user 2h 51min 25s, sys: 5h 43min 48s, total: 8h 35min 13s
# Wall time: 1h 24min 39s

# %%
# %%time
layer_sizes = [200] * 4

lrs = [0.07, 0.1, 0.3, 0.5]
alphas = [3e-5, 7e-5, 1e-4]

n_epochs = 50


fig = plt.figure(figsize=(20, 10))
i = 0
for alpha, lr in itertools.product(alphas, lrs):
    i += 1
    train_log, val_log = build_and_train2(layer_sizes, lr, alpha, n_epochs)

    ax = plt.subplot(len(alphas), len(lrs), i) 
    display_learning_curve2(ax, train_log, val_log, lr, alpha)
# Out:
# Training with and lr = 0.07 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9563, val acc = 0.9578
# epoch =  1, train acc = 0.9713, val acc = 0.9664
# epoch =  2, train acc = 0.9806, val acc = 0.9724
# epoch =  3, train acc = 0.9833, val acc = 0.9723
# epoch =  4, train acc = 0.9874, val acc = 0.9751
# epoch =  5, train acc = 0.9922, val acc = 0.9777
# epoch =  6, train acc = 0.9932, val acc = 0.9791
# epoch =  7, train acc = 0.9913, val acc = 0.9770
# epoch =  8, train acc = 0.9924, val acc = 0.9782
# epoch =  9, train acc = 0.9954, val acc = 0.9794
# epoch = 10, train acc = 0.9958, val acc = 0.9790
# epoch = 11, train acc = 0.9960, val acc = 0.9787
# epoch = 12, train acc = 0.9978, val acc = 0.9800
# epoch = 13, train acc = 0.9959, val acc = 0.9788
# epoch = 14, train acc = 0.9976, val acc = 0.9800
# epoch = 15, train acc = 0.9933, val acc = 0.9758
# epoch = 16, train acc = 0.9987, val acc = 0.9801
# epoch = 17, train acc = 0.9975, val acc = 0.9790
# epoch = 18, train acc = 0.9984, val acc = 0.9796
# epoch = 19, train acc = 0.9922, val acc = 0.9747
# epoch = 20, train acc = 0.9985, val acc = 0.9814
# epoch = 21, train acc = 0.9991, val acc = 0.9812
# epoch = 22, train acc = 0.9991, val acc = 0.9824
# epoch = 23, train acc = 0.9982, val acc = 0.9788
# epoch = 24, train acc = 0.9960, val acc = 0.9781
# epoch = 25, train acc = 0.9996, val acc = 0.9821
# epoch = 26, train acc = 0.9992, val acc = 0.9820
# epoch = 27, train acc = 0.9961, val acc = 0.9767
# epoch = 28, train acc = 0.9967, val acc = 0.9804
# epoch = 29, train acc = 0.9966, val acc = 0.9800
# epoch = 30, train acc = 0.9992, val acc = 0.9846
# epoch = 31, train acc = 0.9975, val acc = 0.9809
# epoch = 32, train acc = 0.9972, val acc = 0.9791
# epoch = 33, train acc = 0.9967, val acc = 0.9783
# epoch = 34, train acc = 0.9998, val acc = 0.9840
# epoch = 35, train acc = 1.0000, val acc = 0.9825
# epoch = 36, train acc = 0.9994, val acc = 0.9823
# epoch = 37, train acc = 0.9973, val acc = 0.9788
# epoch = 38, train acc = 0.9904, val acc = 0.9758
# epoch = 39, train acc = 0.9956, val acc = 0.9763
# epoch = 40, train acc = 0.9935, val acc = 0.9788
# epoch = 41, train acc = 0.9979, val acc = 0.9813
# epoch = 42, train acc = 0.9988, val acc = 0.9807
# epoch = 43, train acc = 0.9998, val acc = 0.9836
# epoch = 44, train acc = 0.9998, val acc = 0.9818
# epoch = 45, train acc = 0.9999, val acc = 0.9840
# epoch = 46, train acc = 1.0000, val acc = 0.9830
# epoch = 47, train acc = 0.9999, val acc = 0.9833
# epoch = 48, train acc = 0.9983, val acc = 0.9803
# epoch = 49, train acc = 0.9949, val acc = 0.9777
#
# Training with and lr = 0.1 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9598, val acc = 0.9593
# epoch =  1, train acc = 0.9713, val acc = 0.9651
# epoch =  2, train acc = 0.9771, val acc = 0.9691
# epoch =  3, train acc = 0.9854, val acc = 0.9745
# epoch =  4, train acc = 0.9846, val acc = 0.9696
# epoch =  5, train acc = 0.9664, val acc = 0.9568
# epoch =  6, train acc = 0.9859, val acc = 0.9729
# epoch =  7, train acc = 0.9921, val acc = 0.9766
# epoch =  8, train acc = 0.9934, val acc = 0.9762
# epoch =  9, train acc = 0.9973, val acc = 0.9812
# epoch = 10, train acc = 0.9939, val acc = 0.9789
# epoch = 11, train acc = 0.9883, val acc = 0.9721
# epoch = 12, train acc = 0.9961, val acc = 0.9790
# epoch = 13, train acc = 0.9984, val acc = 0.9812
# epoch = 14, train acc = 0.9967, val acc = 0.9792
# epoch = 15, train acc = 0.9933, val acc = 0.9744
# epoch = 16, train acc = 0.9968, val acc = 0.9780
# epoch = 17, train acc = 0.9946, val acc = 0.9778
# epoch = 18, train acc = 0.9972, val acc = 0.9794
# epoch = 19, train acc = 0.9989, val acc = 0.9811
# epoch = 20, train acc = 0.9992, val acc = 0.9812
# epoch = 21, train acc = 0.9996, val acc = 0.9822
# epoch = 22, train acc = 0.9924, val acc = 0.9748
# epoch = 23, train acc = 0.9975, val acc = 0.9792
# epoch = 24, train acc = 0.9983, val acc = 0.9795
# epoch = 25, train acc = 0.9980, val acc = 0.9809
# epoch = 26, train acc = 0.9997, val acc = 0.9812
# epoch = 27, train acc = 0.9988, val acc = 0.9805
# epoch = 28, train acc = 0.9984, val acc = 0.9794
# epoch = 29, train acc = 0.9986, val acc = 0.9797
# epoch = 30, train acc = 0.9972, val acc = 0.9804
# epoch = 31, train acc = 0.9962, val acc = 0.9781
# epoch = 32, train acc = 0.9965, val acc = 0.9766
# epoch = 33, train acc = 0.9975, val acc = 0.9778
# epoch = 34, train acc = 0.9941, val acc = 0.9756
# epoch = 35, train acc = 0.9974, val acc = 0.9792
# epoch = 36, train acc = 0.9972, val acc = 0.9798
# epoch = 37, train acc = 0.9971, val acc = 0.9801
# epoch = 38, train acc = 0.9975, val acc = 0.9788
# epoch = 39, train acc = 0.9997, val acc = 0.9820
# epoch = 40, train acc = 0.9993, val acc = 0.9823
# epoch = 41, train acc = 0.9993, val acc = 0.9805
# epoch = 42, train acc = 0.9994, val acc = 0.9825
# epoch = 43, train acc = 0.9952, val acc = 0.9778
# epoch = 44, train acc = 0.9949, val acc = 0.9783
# epoch = 45, train acc = 0.9942, val acc = 0.9776
# epoch = 46, train acc = 0.9930, val acc = 0.9746
# epoch = 47, train acc = 0.9932, val acc = 0.9740
# epoch = 48, train acc = 0.9944, val acc = 0.9758
# epoch = 49, train acc = 0.9997, val acc = 0.9816
#
# Training with and lr = 0.3 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9560, val acc = 0.9548
# epoch =  1, train acc = 0.9717, val acc = 0.9656
# epoch =  2, train acc = 0.9756, val acc = 0.9645
# epoch =  3, train acc = 0.9779, val acc = 0.9683
# epoch =  4, train acc = 0.9825, val acc = 0.9686
# epoch =  5, train acc = 0.9821, val acc = 0.9693
# epoch =  6, train acc = 0.9886, val acc = 0.9730
# epoch =  7, train acc = 0.9912, val acc = 0.9743
# epoch =  8, train acc = 0.9887, val acc = 0.9706
# epoch =  9, train acc = 0.9886, val acc = 0.9717
# epoch = 10, train acc = 0.9900, val acc = 0.9738
# epoch = 11, train acc = 0.9923, val acc = 0.9736
# epoch = 12, train acc = 0.9880, val acc = 0.9715
# epoch = 13, train acc = 0.9935, val acc = 0.9776
# epoch = 14, train acc = 0.9892, val acc = 0.9685
# epoch = 15, train acc = 0.9938, val acc = 0.9759
# epoch = 16, train acc = 0.9929, val acc = 0.9752
# epoch = 17, train acc = 0.9948, val acc = 0.9756
# epoch = 18, train acc = 0.9888, val acc = 0.9712
# epoch = 19, train acc = 0.9890, val acc = 0.9722
# epoch = 20, train acc = 0.9944, val acc = 0.9775
# epoch = 21, train acc = 0.9896, val acc = 0.9739
# epoch = 22, train acc = 0.9926, val acc = 0.9749
# epoch = 23, train acc = 0.9957, val acc = 0.9781
# epoch = 24, train acc = 0.9840, val acc = 0.9659
# epoch = 25, train acc = 0.9910, val acc = 0.9721
# epoch = 26, train acc = 0.9948, val acc = 0.9755
# epoch = 27, train acc = 0.9926, val acc = 0.9752
# epoch = 28, train acc = 0.9916, val acc = 0.9732
# epoch = 29, train acc = 0.9926, val acc = 0.9751
# epoch = 30, train acc = 0.9947, val acc = 0.9751
# epoch = 31, train acc = 0.9940, val acc = 0.9753
# epoch = 32, train acc = 0.9953, val acc = 0.9765
# epoch = 33, train acc = 0.9950, val acc = 0.9767
# epoch = 34, train acc = 0.9918, val acc = 0.9740
# epoch = 35, train acc = 0.9967, val acc = 0.9779
# epoch = 36, train acc = 0.9954, val acc = 0.9771
# epoch = 37, train acc = 0.9947, val acc = 0.9760
# epoch = 38, train acc = 0.9915, val acc = 0.9742
# epoch = 39, train acc = 0.9971, val acc = 0.9798
# epoch = 40, train acc = 0.9957, val acc = 0.9778
# epoch = 41, train acc = 0.9920, val acc = 0.9752
# epoch = 42, train acc = 0.9973, val acc = 0.9786
# epoch = 43, train acc = 0.9835, val acc = 0.9669
# epoch = 44, train acc = 0.9958, val acc = 0.9781
# epoch = 45, train acc = 0.9963, val acc = 0.9776
# epoch = 46, train acc = 0.9942, val acc = 0.9773
# epoch = 47, train acc = 0.9941, val acc = 0.9755
# epoch = 48, train acc = 0.9945, val acc = 0.9758
# epoch = 49, train acc = 0.9946, val acc = 0.9772
#
# Training with and lr = 0.5 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9550, val acc = 0.9563
# epoch =  1, train acc = 0.9681, val acc = 0.9618
# epoch =  2, train acc = 0.9772, val acc = 0.9718
# epoch =  3, train acc = 0.9787, val acc = 0.9695
# epoch =  4, train acc = 0.9807, val acc = 0.9707
# epoch =  5, train acc = 0.9828, val acc = 0.9695
# epoch =  6, train acc = 0.9788, val acc = 0.9643
# epoch =  7, train acc = 0.9905, val acc = 0.9751
# epoch =  8, train acc = 0.9871, val acc = 0.9720
# epoch =  9, train acc = 0.9910, val acc = 0.9765
# epoch = 10, train acc = 0.9869, val acc = 0.9701
# epoch = 11, train acc = 0.9870, val acc = 0.9693
# epoch = 12, train acc = 0.9867, val acc = 0.9719
# epoch = 13, train acc = 0.9899, val acc = 0.9740
# epoch = 14, train acc = 0.9906, val acc = 0.9760
# epoch = 15, train acc = 0.9894, val acc = 0.9750
# epoch = 16, train acc = 0.9914, val acc = 0.9753
# epoch = 17, train acc = 0.9741, val acc = 0.9582
# epoch = 18, train acc = 0.9344, val acc = 0.9158
# epoch = 19, train acc = 0.9916, val acc = 0.9737
# epoch = 20, train acc = 0.9939, val acc = 0.9763
# epoch = 21, train acc = 0.9910, val acc = 0.9727
# epoch = 22, train acc = 0.9809, val acc = 0.9644
# epoch = 23, train acc = 0.9926, val acc = 0.9717
# epoch = 24, train acc = 0.9928, val acc = 0.9733
# epoch = 25, train acc = 0.9923, val acc = 0.9745
# epoch = 26, train acc = 0.9920, val acc = 0.9750
# epoch = 27, train acc = 0.9923, val acc = 0.9761
# epoch = 28, train acc = 0.9937, val acc = 0.9764
# epoch = 29, train acc = 0.9885, val acc = 0.9713
# epoch = 30, train acc = 0.9952, val acc = 0.9769
# epoch = 31, train acc = 0.9938, val acc = 0.9753
# epoch = 32, train acc = 0.9950, val acc = 0.9763
# epoch = 33, train acc = 0.9962, val acc = 0.9794
# epoch = 34, train acc = 0.9968, val acc = 0.9788
# epoch = 35, train acc = 0.9833, val acc = 0.9673
# epoch = 36, train acc = 0.9952, val acc = 0.9771
# epoch = 37, train acc = 0.9929, val acc = 0.9724
# epoch = 38, train acc = 0.9899, val acc = 0.9717
# epoch = 39, train acc = 0.9916, val acc = 0.9739
# epoch = 40, train acc = 0.9960, val acc = 0.9776
# epoch = 41, train acc = 0.9928, val acc = 0.9730
# epoch = 42, train acc = 0.9932, val acc = 0.9748
# epoch = 43, train acc = 0.9906, val acc = 0.9749
# epoch = 44, train acc = 0.9826, val acc = 0.9682
# epoch = 45, train acc = 0.9951, val acc = 0.9773
# epoch = 46, train acc = 0.9910, val acc = 0.9735
# epoch = 47, train acc = 0.9937, val acc = 0.9766
# epoch = 48, train acc = 0.9919, val acc = 0.9758
# epoch = 49, train acc = 0.9921, val acc = 0.9745
#
# Training with and lr = 0.07 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9525, val acc = 0.9545
# epoch =  1, train acc = 0.9673, val acc = 0.9641
# epoch =  2, train acc = 0.9790, val acc = 0.9717
# epoch =  3, train acc = 0.9825, val acc = 0.9732
# epoch =  4, train acc = 0.9862, val acc = 0.9759
# epoch =  5, train acc = 0.9888, val acc = 0.9767
# epoch =  6, train acc = 0.9890, val acc = 0.9755
# epoch =  7, train acc = 0.9901, val acc = 0.9763
# epoch =  8, train acc = 0.9932, val acc = 0.9806
# epoch =  9, train acc = 0.9922, val acc = 0.9780
# epoch = 10, train acc = 0.9904, val acc = 0.9750
# epoch = 11, train acc = 0.9896, val acc = 0.9749
# epoch = 12, train acc = 0.9929, val acc = 0.9787
# epoch = 13, train acc = 0.9955, val acc = 0.9793
# epoch = 14, train acc = 0.9938, val acc = 0.9796
# epoch = 15, train acc = 0.9950, val acc = 0.9792
# epoch = 16, train acc = 0.9933, val acc = 0.9801
# epoch = 17, train acc = 0.9939, val acc = 0.9772
# epoch = 18, train acc = 0.9960, val acc = 0.9815
# epoch = 19, train acc = 0.9936, val acc = 0.9799
# epoch = 20, train acc = 0.9943, val acc = 0.9783
# epoch = 21, train acc = 0.9906, val acc = 0.9741
# epoch = 22, train acc = 0.9937, val acc = 0.9783
# epoch = 23, train acc = 0.9965, val acc = 0.9818
# epoch = 24, train acc = 0.9955, val acc = 0.9800
# epoch = 25, train acc = 0.9944, val acc = 0.9802
# epoch = 26, train acc = 0.9940, val acc = 0.9793
# epoch = 27, train acc = 0.9914, val acc = 0.9741
# epoch = 28, train acc = 0.9908, val acc = 0.9734
# epoch = 29, train acc = 0.9823, val acc = 0.9681
# epoch = 30, train acc = 0.9974, val acc = 0.9804
# epoch = 31, train acc = 0.9947, val acc = 0.9799
# epoch = 32, train acc = 0.9964, val acc = 0.9796
# epoch = 33, train acc = 0.9955, val acc = 0.9781
# epoch = 34, train acc = 0.9958, val acc = 0.9797
# epoch = 35, train acc = 0.9957, val acc = 0.9794
# epoch = 36, train acc = 0.9946, val acc = 0.9788
# epoch = 37, train acc = 0.9919, val acc = 0.9760
# epoch = 38, train acc = 0.9911, val acc = 0.9761
# epoch = 39, train acc = 0.9886, val acc = 0.9741
# epoch = 40, train acc = 0.9936, val acc = 0.9784
# epoch = 41, train acc = 0.9963, val acc = 0.9799
# epoch = 42, train acc = 0.9933, val acc = 0.9785
# epoch = 43, train acc = 0.9951, val acc = 0.9793
# epoch = 44, train acc = 0.9925, val acc = 0.9792
# epoch = 45, train acc = 0.9931, val acc = 0.9773
# epoch = 46, train acc = 0.9952, val acc = 0.9818
# epoch = 47, train acc = 0.9949, val acc = 0.9789
# epoch = 48, train acc = 0.9949, val acc = 0.9797
# epoch = 49, train acc = 0.9962, val acc = 0.9791
#
# Training with and lr = 0.1 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9594, val acc = 0.9588
# epoch =  1, train acc = 0.9767, val acc = 0.9705
# epoch =  2, train acc = 0.9836, val acc = 0.9763
# epoch =  3, train acc = 0.9818, val acc = 0.9711
# epoch =  4, train acc = 0.9834, val acc = 0.9738
# epoch =  5, train acc = 0.9894, val acc = 0.9770
# epoch =  6, train acc = 0.9711, val acc = 0.9629
# epoch =  7, train acc = 0.9928, val acc = 0.9788
# epoch =  8, train acc = 0.9905, val acc = 0.9777
# epoch =  9, train acc = 0.9935, val acc = 0.9786
# epoch = 10, train acc = 0.9897, val acc = 0.9767
# epoch = 11, train acc = 0.9857, val acc = 0.9717
# epoch = 12, train acc = 0.9909, val acc = 0.9765
# epoch = 13, train acc = 0.9938, val acc = 0.9771
# epoch = 14, train acc = 0.9922, val acc = 0.9776
# epoch = 15, train acc = 0.9880, val acc = 0.9754
# epoch = 16, train acc = 0.9857, val acc = 0.9712
# epoch = 17, train acc = 0.9941, val acc = 0.9792
# epoch = 18, train acc = 0.9953, val acc = 0.9799
# epoch = 19, train acc = 0.9941, val acc = 0.9783
# epoch = 20, train acc = 0.9898, val acc = 0.9752
# epoch = 21, train acc = 0.9955, val acc = 0.9803
# epoch = 22, train acc = 0.9925, val acc = 0.9755
# epoch = 23, train acc = 0.9956, val acc = 0.9816
# epoch = 24, train acc = 0.9928, val acc = 0.9782
# epoch = 25, train acc = 0.9890, val acc = 0.9749
# epoch = 26, train acc = 0.9917, val acc = 0.9779
# epoch = 27, train acc = 0.9942, val acc = 0.9781
# epoch = 28, train acc = 0.9932, val acc = 0.9762
# epoch = 29, train acc = 0.9930, val acc = 0.9769
# epoch = 30, train acc = 0.9887, val acc = 0.9722
# epoch = 31, train acc = 0.9955, val acc = 0.9790
# epoch = 32, train acc = 0.9957, val acc = 0.9798
# epoch = 33, train acc = 0.9907, val acc = 0.9736
# epoch = 34, train acc = 0.9936, val acc = 0.9773
# epoch = 35, train acc = 0.9888, val acc = 0.9704
# epoch = 36, train acc = 0.9968, val acc = 0.9801
# epoch = 37, train acc = 0.9920, val acc = 0.9768
# epoch = 38, train acc = 0.9879, val acc = 0.9730
# epoch = 39, train acc = 0.9949, val acc = 0.9792
# epoch = 40, train acc = 0.9954, val acc = 0.9811
# epoch = 41, train acc = 0.9975, val acc = 0.9817
# epoch = 42, train acc = 0.9924, val acc = 0.9761
# epoch = 43, train acc = 0.9938, val acc = 0.9779
# epoch = 44, train acc = 0.9935, val acc = 0.9796
# epoch = 45, train acc = 0.9935, val acc = 0.9776
# epoch = 46, train acc = 0.9963, val acc = 0.9803
# epoch = 47, train acc = 0.9915, val acc = 0.9765
# epoch = 48, train acc = 0.9955, val acc = 0.9786
# epoch = 49, train acc = 0.9899, val acc = 0.9739
#
# Training with and lr = 0.3 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9619, val acc = 0.9620
# epoch =  1, train acc = 0.9714, val acc = 0.9636
# epoch =  2, train acc = 0.9787, val acc = 0.9706
# epoch =  3, train acc = 0.9794, val acc = 0.9730
# epoch =  4, train acc = 0.9862, val acc = 0.9740
# epoch =  5, train acc = 0.9847, val acc = 0.9722
# epoch =  6, train acc = 0.9854, val acc = 0.9727
# epoch =  7, train acc = 0.9849, val acc = 0.9733
# epoch =  8, train acc = 0.9896, val acc = 0.9753
# epoch =  9, train acc = 0.9785, val acc = 0.9662
# epoch = 10, train acc = 0.9899, val acc = 0.9755
# epoch = 11, train acc = 0.9848, val acc = 0.9716
# epoch = 12, train acc = 0.9882, val acc = 0.9751
# epoch = 13, train acc = 0.9912, val acc = 0.9764
# epoch = 14, train acc = 0.9898, val acc = 0.9761
# epoch = 15, train acc = 0.9911, val acc = 0.9767
# epoch = 16, train acc = 0.9919, val acc = 0.9791
# epoch = 17, train acc = 0.9927, val acc = 0.9775
# epoch = 18, train acc = 0.9914, val acc = 0.9775
# epoch = 19, train acc = 0.9939, val acc = 0.9815
# epoch = 20, train acc = 0.9941, val acc = 0.9801
# epoch = 21, train acc = 0.9945, val acc = 0.9813
# epoch = 22, train acc = 0.9876, val acc = 0.9748
# epoch = 23, train acc = 0.9911, val acc = 0.9773
# epoch = 24, train acc = 0.9862, val acc = 0.9711
# epoch = 25, train acc = 0.9941, val acc = 0.9791
# epoch = 26, train acc = 0.9892, val acc = 0.9738
# epoch = 27, train acc = 0.9856, val acc = 0.9719
# epoch = 28, train acc = 0.9929, val acc = 0.9791
# epoch = 29, train acc = 0.9893, val acc = 0.9774
# epoch = 30, train acc = 0.9888, val acc = 0.9748
# epoch = 31, train acc = 0.9938, val acc = 0.9793
# epoch = 32, train acc = 0.9881, val acc = 0.9743
# epoch = 33, train acc = 0.9894, val acc = 0.9729
# epoch = 34, train acc = 0.9911, val acc = 0.9766
# epoch = 35, train acc = 0.9951, val acc = 0.9801
# epoch = 36, train acc = 0.9931, val acc = 0.9793
# epoch = 37, train acc = 0.9931, val acc = 0.9756
# epoch = 38, train acc = 0.9933, val acc = 0.9810
# epoch = 39, train acc = 0.9921, val acc = 0.9784
# epoch = 40, train acc = 0.9881, val acc = 0.9738
# epoch = 41, train acc = 0.9911, val acc = 0.9771
# epoch = 42, train acc = 0.9894, val acc = 0.9721
# epoch = 43, train acc = 0.9925, val acc = 0.9789
# epoch = 44, train acc = 0.9918, val acc = 0.9774
# epoch = 45, train acc = 0.9910, val acc = 0.9740
# epoch = 46, train acc = 0.9902, val acc = 0.9770
# epoch = 47, train acc = 0.9891, val acc = 0.9739
# epoch = 48, train acc = 0.9889, val acc = 0.9736
# epoch = 49, train acc = 0.9891, val acc = 0.9764
#
# Training with and lr = 0.5 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9553, val acc = 0.9557
# epoch =  1, train acc = 0.9694, val acc = 0.9641
# epoch =  2, train acc = 0.9737, val acc = 0.9673
# epoch =  3, train acc = 0.9738, val acc = 0.9651
# epoch =  4, train acc = 0.9769, val acc = 0.9676
# epoch =  5, train acc = 0.9770, val acc = 0.9679
# epoch =  6, train acc = 0.9838, val acc = 0.9729
# epoch =  7, train acc = 0.9713, val acc = 0.9615
# epoch =  8, train acc = 0.9802, val acc = 0.9679
# epoch =  9, train acc = 0.9751, val acc = 0.9601
# epoch = 10, train acc = 0.9858, val acc = 0.9717
# epoch = 11, train acc = 0.9846, val acc = 0.9712
# epoch = 12, train acc = 0.9862, val acc = 0.9741
# epoch = 13, train acc = 0.9871, val acc = 0.9738
# epoch = 14, train acc = 0.9824, val acc = 0.9697
# epoch = 15, train acc = 0.9788, val acc = 0.9676
# epoch = 16, train acc = 0.9893, val acc = 0.9769
# epoch = 17, train acc = 0.9886, val acc = 0.9731
# epoch = 18, train acc = 0.9857, val acc = 0.9742
# epoch = 19, train acc = 0.9904, val acc = 0.9764
# epoch = 20, train acc = 0.9909, val acc = 0.9751
# epoch = 21, train acc = 0.9602, val acc = 0.9473
# epoch = 22, train acc = 0.9908, val acc = 0.9767
# epoch = 23, train acc = 0.9840, val acc = 0.9718
# epoch = 24, train acc = 0.9876, val acc = 0.9751
# epoch = 25, train acc = 0.9770, val acc = 0.9643
# epoch = 26, train acc = 0.9893, val acc = 0.9743
# epoch = 27, train acc = 0.9887, val acc = 0.9745
# epoch = 28, train acc = 0.9897, val acc = 0.9742
# epoch = 29, train acc = 0.9868, val acc = 0.9729
# epoch = 30, train acc = 0.9925, val acc = 0.9784
# epoch = 31, train acc = 0.9900, val acc = 0.9763
# epoch = 32, train acc = 0.9903, val acc = 0.9758
# epoch = 33, train acc = 0.9909, val acc = 0.9771
# epoch = 34, train acc = 0.9867, val acc = 0.9743
# epoch = 35, train acc = 0.9836, val acc = 0.9707
# epoch = 36, train acc = 0.9856, val acc = 0.9721
# epoch = 37, train acc = 0.9936, val acc = 0.9793
# epoch = 38, train acc = 0.9847, val acc = 0.9734
# epoch = 39, train acc = 0.9896, val acc = 0.9734
# epoch = 40, train acc = 0.9865, val acc = 0.9730
# epoch = 41, train acc = 0.9872, val acc = 0.9739
# epoch = 42, train acc = 0.9779, val acc = 0.9647
# epoch = 43, train acc = 0.9887, val acc = 0.9739
# epoch = 44, train acc = 0.9916, val acc = 0.9762
# epoch = 45, train acc = 0.9867, val acc = 0.9724
# epoch = 46, train acc = 0.9935, val acc = 0.9781
# epoch = 47, train acc = 0.9887, val acc = 0.9730
# epoch = 48, train acc = 0.9897, val acc = 0.9756
# epoch = 49, train acc = 0.9888, val acc = 0.9752
#
# Training with and lr = 0.07 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9557, val acc = 0.9560
# epoch =  1, train acc = 0.9631, val acc = 0.9609
# epoch =  2, train acc = 0.9774, val acc = 0.9722
# epoch =  3, train acc = 0.9774, val acc = 0.9693
# epoch =  4, train acc = 0.9850, val acc = 0.9750
# epoch =  5, train acc = 0.9886, val acc = 0.9779
# epoch =  6, train acc = 0.9830, val acc = 0.9726
# epoch =  7, train acc = 0.9889, val acc = 0.9782
# epoch =  8, train acc = 0.9834, val acc = 0.9709
# epoch =  9, train acc = 0.9911, val acc = 0.9773
# epoch = 10, train acc = 0.9906, val acc = 0.9770
# epoch = 11, train acc = 0.9917, val acc = 0.9786
# epoch = 12, train acc = 0.9903, val acc = 0.9789
# epoch = 13, train acc = 0.9896, val acc = 0.9761
# epoch = 14, train acc = 0.9924, val acc = 0.9787
# epoch = 15, train acc = 0.9883, val acc = 0.9746
# epoch = 16, train acc = 0.9914, val acc = 0.9794
# epoch = 17, train acc = 0.9911, val acc = 0.9779
# epoch = 18, train acc = 0.9885, val acc = 0.9763
# epoch = 19, train acc = 0.9908, val acc = 0.9754
# epoch = 20, train acc = 0.9908, val acc = 0.9779
# epoch = 21, train acc = 0.9909, val acc = 0.9771
# epoch = 22, train acc = 0.9922, val acc = 0.9785
# epoch = 23, train acc = 0.9904, val acc = 0.9754
# epoch = 24, train acc = 0.9896, val acc = 0.9748
# epoch = 25, train acc = 0.9918, val acc = 0.9760
# epoch = 26, train acc = 0.9932, val acc = 0.9780
# epoch = 27, train acc = 0.9902, val acc = 0.9766
# epoch = 28, train acc = 0.9877, val acc = 0.9731
# epoch = 29, train acc = 0.9938, val acc = 0.9780
# epoch = 30, train acc = 0.9899, val acc = 0.9783
# epoch = 31, train acc = 0.9871, val acc = 0.9735
# epoch = 32, train acc = 0.9849, val acc = 0.9703
# epoch = 33, train acc = 0.9733, val acc = 0.9623
# epoch = 34, train acc = 0.9915, val acc = 0.9754
# epoch = 35, train acc = 0.9943, val acc = 0.9794
# epoch = 36, train acc = 0.9856, val acc = 0.9738
# epoch = 37, train acc = 0.9895, val acc = 0.9736
# epoch = 38, train acc = 0.9900, val acc = 0.9756
# epoch = 39, train acc = 0.9853, val acc = 0.9694
# epoch = 40, train acc = 0.9947, val acc = 0.9792
# epoch = 41, train acc = 0.9941, val acc = 0.9782
# epoch = 42, train acc = 0.9946, val acc = 0.9795
# epoch = 43, train acc = 0.9905, val acc = 0.9761
# epoch = 44, train acc = 0.9938, val acc = 0.9782
# epoch = 45, train acc = 0.9912, val acc = 0.9761
# epoch = 46, train acc = 0.9910, val acc = 0.9750
# epoch = 47, train acc = 0.9698, val acc = 0.9546
# epoch = 48, train acc = 0.9859, val acc = 0.9732
# epoch = 49, train acc = 0.9898, val acc = 0.9760
#
# Training with and lr = 0.1 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9572, val acc = 0.9563
# epoch =  1, train acc = 0.9767, val acc = 0.9718
# epoch =  2, train acc = 0.9802, val acc = 0.9734
# epoch =  3, train acc = 0.9794, val acc = 0.9714
# epoch =  4, train acc = 0.9869, val acc = 0.9767
# epoch =  5, train acc = 0.9823, val acc = 0.9735
# epoch =  6, train acc = 0.9610, val acc = 0.9521
# epoch =  7, train acc = 0.9890, val acc = 0.9758
# epoch =  8, train acc = 0.9853, val acc = 0.9737
# epoch =  9, train acc = 0.9892, val acc = 0.9770
# epoch = 10, train acc = 0.9849, val acc = 0.9707
# epoch = 11, train acc = 0.9906, val acc = 0.9775
# epoch = 12, train acc = 0.9761, val acc = 0.9660
# epoch = 13, train acc = 0.9923, val acc = 0.9778
# epoch = 14, train acc = 0.9901, val acc = 0.9784
# epoch = 15, train acc = 0.9878, val acc = 0.9734
# epoch = 16, train acc = 0.9935, val acc = 0.9807
# epoch = 17, train acc = 0.9895, val acc = 0.9741
# epoch = 18, train acc = 0.9924, val acc = 0.9777
# epoch = 19, train acc = 0.9932, val acc = 0.9777
# epoch = 20, train acc = 0.9941, val acc = 0.9784
# epoch = 21, train acc = 0.9911, val acc = 0.9760
# epoch = 22, train acc = 0.9813, val acc = 0.9682
# epoch = 23, train acc = 0.9927, val acc = 0.9783
# epoch = 24, train acc = 0.9925, val acc = 0.9787
# epoch = 25, train acc = 0.9933, val acc = 0.9783
# epoch = 26, train acc = 0.9814, val acc = 0.9678
# epoch = 27, train acc = 0.9933, val acc = 0.9763
# epoch = 28, train acc = 0.9870, val acc = 0.9739
# epoch = 29, train acc = 0.9903, val acc = 0.9757
# epoch = 30, train acc = 0.9935, val acc = 0.9792
# epoch = 31, train acc = 0.9925, val acc = 0.9767
# epoch = 32, train acc = 0.9926, val acc = 0.9787
# epoch = 33, train acc = 0.9926, val acc = 0.9780
# epoch = 34, train acc = 0.9912, val acc = 0.9782
# epoch = 35, train acc = 0.9943, val acc = 0.9807
# epoch = 36, train acc = 0.9925, val acc = 0.9781
# epoch = 37, train acc = 0.9942, val acc = 0.9818
# epoch = 38, train acc = 0.9883, val acc = 0.9733
# epoch = 39, train acc = 0.9934, val acc = 0.9793
# epoch = 40, train acc = 0.9909, val acc = 0.9765
# epoch = 41, train acc = 0.9750, val acc = 0.9614
# epoch = 42, train acc = 0.9914, val acc = 0.9766
# epoch = 43, train acc = 0.9873, val acc = 0.9741
# epoch = 44, train acc = 0.9909, val acc = 0.9772
# epoch = 45, train acc = 0.9897, val acc = 0.9748
# epoch = 46, train acc = 0.9913, val acc = 0.9776
# epoch = 47, train acc = 0.9929, val acc = 0.9778
# epoch = 48, train acc = 0.9931, val acc = 0.9783
# epoch = 49, train acc = 0.9890, val acc = 0.9755
#
# Training with and lr = 0.3 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9594, val acc = 0.9575
# epoch =  1, train acc = 0.9680, val acc = 0.9597
# epoch =  2, train acc = 0.9781, val acc = 0.9692
# epoch =  3, train acc = 0.9833, val acc = 0.9714
# epoch =  4, train acc = 0.9848, val acc = 0.9724
# epoch =  5, train acc = 0.9772, val acc = 0.9689
# epoch =  6, train acc = 0.9811, val acc = 0.9685
# epoch =  7, train acc = 0.9872, val acc = 0.9753
# epoch =  8, train acc = 0.9847, val acc = 0.9729
# epoch =  9, train acc = 0.9886, val acc = 0.9773
# epoch = 10, train acc = 0.9870, val acc = 0.9754
# epoch = 11, train acc = 0.9804, val acc = 0.9683
# epoch = 12, train acc = 0.9843, val acc = 0.9730
# epoch = 13, train acc = 0.9859, val acc = 0.9761
# epoch = 14, train acc = 0.9836, val acc = 0.9727
# epoch = 15, train acc = 0.9886, val acc = 0.9759
# epoch = 16, train acc = 0.9857, val acc = 0.9722
# epoch = 17, train acc = 0.9818, val acc = 0.9717
# epoch = 18, train acc = 0.9890, val acc = 0.9747
# epoch = 19, train acc = 0.9855, val acc = 0.9751
# epoch = 20, train acc = 0.9889, val acc = 0.9765
# epoch = 21, train acc = 0.9899, val acc = 0.9783
# epoch = 22, train acc = 0.9865, val acc = 0.9748
# epoch = 23, train acc = 0.9839, val acc = 0.9726
# epoch = 24, train acc = 0.9824, val acc = 0.9697
# epoch = 25, train acc = 0.9898, val acc = 0.9778
# epoch = 26, train acc = 0.9837, val acc = 0.9720
# epoch = 27, train acc = 0.9877, val acc = 0.9763
# epoch = 28, train acc = 0.9919, val acc = 0.9791
# epoch = 29, train acc = 0.9929, val acc = 0.9785
# epoch = 30, train acc = 0.9839, val acc = 0.9730
# epoch = 31, train acc = 0.9903, val acc = 0.9772
# epoch = 32, train acc = 0.9914, val acc = 0.9762
# epoch = 33, train acc = 0.9916, val acc = 0.9793
# epoch = 34, train acc = 0.9901, val acc = 0.9750
# epoch = 35, train acc = 0.9819, val acc = 0.9693
# epoch = 36, train acc = 0.9897, val acc = 0.9772
# epoch = 37, train acc = 0.9860, val acc = 0.9724
# epoch = 38, train acc = 0.9883, val acc = 0.9764
# epoch = 39, train acc = 0.9860, val acc = 0.9736
# epoch = 40, train acc = 0.9915, val acc = 0.9791
# epoch = 41, train acc = 0.9916, val acc = 0.9769
# epoch = 42, train acc = 0.9917, val acc = 0.9761
# epoch = 43, train acc = 0.9894, val acc = 0.9764
# epoch = 44, train acc = 0.9901, val acc = 0.9766
# epoch = 45, train acc = 0.9900, val acc = 0.9752
# epoch = 46, train acc = 0.9818, val acc = 0.9690
# epoch = 47, train acc = 0.9857, val acc = 0.9720
# epoch = 48, train acc = 0.9826, val acc = 0.9700
# epoch = 49, train acc = 0.9863, val acc = 0.9713
#
# Training with and lr = 0.5 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9547, val acc = 0.9548
# epoch =  1, train acc = 0.9405, val acc = 0.9348
# epoch =  2, train acc = 0.9483, val acc = 0.9448
# epoch =  3, train acc = 0.9714, val acc = 0.9636
# epoch =  4, train acc = 0.9763, val acc = 0.9658
# epoch =  5, train acc = 0.9679, val acc = 0.9589
# epoch =  6, train acc = 0.9795, val acc = 0.9699
# epoch =  7, train acc = 0.9813, val acc = 0.9697
# epoch =  8, train acc = 0.9840, val acc = 0.9753
# epoch =  9, train acc = 0.9847, val acc = 0.9726
# epoch = 10, train acc = 0.9828, val acc = 0.9710
# epoch = 11, train acc = 0.9815, val acc = 0.9685
# epoch = 12, train acc = 0.9848, val acc = 0.9716
# epoch = 13, train acc = 0.9874, val acc = 0.9750
# epoch = 14, train acc = 0.9782, val acc = 0.9676
# epoch = 15, train acc = 0.9877, val acc = 0.9753
# epoch = 16, train acc = 0.9873, val acc = 0.9750
# epoch = 17, train acc = 0.9878, val acc = 0.9761
# epoch = 18, train acc = 0.9668, val acc = 0.9530
# epoch = 19, train acc = 0.9797, val acc = 0.9670
# epoch = 20, train acc = 0.9846, val acc = 0.9712
# epoch = 21, train acc = 0.9836, val acc = 0.9726
# epoch = 22, train acc = 0.9854, val acc = 0.9723
# epoch = 23, train acc = 0.9576, val acc = 0.9478
# epoch = 24, train acc = 0.9882, val acc = 0.9755
# epoch = 25, train acc = 0.9670, val acc = 0.9554
# epoch = 26, train acc = 0.9876, val acc = 0.9748
# epoch = 27, train acc = 0.9876, val acc = 0.9732
# epoch = 28, train acc = 0.9871, val acc = 0.9728
# epoch = 29, train acc = 0.9904, val acc = 0.9787
# epoch = 30, train acc = 0.9871, val acc = 0.9750
# epoch = 31, train acc = 0.9856, val acc = 0.9748
# epoch = 32, train acc = 0.9729, val acc = 0.9608
# epoch = 33, train acc = 0.9884, val acc = 0.9770
# epoch = 34, train acc = 0.9859, val acc = 0.9738
# epoch = 35, train acc = 0.9741, val acc = 0.9612
# epoch = 36, train acc = 0.9870, val acc = 0.9722
# epoch = 37, train acc = 0.9857, val acc = 0.9723
# epoch = 38, train acc = 0.9892, val acc = 0.9767
# epoch = 39, train acc = 0.9811, val acc = 0.9688
# epoch = 40, train acc = 0.9827, val acc = 0.9711
# epoch = 41, train acc = 0.9857, val acc = 0.9725
# epoch = 42, train acc = 0.9882, val acc = 0.9764
# epoch = 43, train acc = 0.9746, val acc = 0.9644
# epoch = 44, train acc = 0.9845, val acc = 0.9739
# epoch = 45, train acc = 0.9885, val acc = 0.9749
# epoch = 46, train acc = 0.9881, val acc = 0.9730
# epoch = 47, train acc = 0.9890, val acc = 0.9756
# epoch = 48, train acc = 0.9868, val acc = 0.9772
# epoch = 49, train acc = 0.9841, val acc = 0.9727
# CPU times: user 12h 51min 55s, sys: 11h 17min 37s, total: 1d 9min 33s
# Wall time: 3h 10min 26s

# %%
# %%time
layer_sizes = [200] * 6

lrs = [0.07, 0.1, 0.3, 0.5]
alphas = [3e-5, 7e-5, 1e-4]

n_epochs = 50


fig = plt.figure(figsize=(20, 10))
i = 0
for alpha, lr in itertools.product(alphas, lrs):
    i += 1
    train_log, val_log = build_and_train2(layer_sizes, lr, alpha, n_epochs)

    ax = plt.subplot(len(alphas), len(lrs), i) 
    display_learning_curve2(ax, train_log, val_log, lr, alpha)
# Out:
# Training with and lr = 0.07 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9594, val acc = 0.9572
# epoch =  1, train acc = 0.9706, val acc = 0.9659
# epoch =  2, train acc = 0.9793, val acc = 0.9726
# epoch =  3, train acc = 0.9846, val acc = 0.9723
# epoch =  4, train acc = 0.9894, val acc = 0.9761
# epoch =  5, train acc = 0.9802, val acc = 0.9683
# epoch =  6, train acc = 0.9902, val acc = 0.9732
# epoch =  7, train acc = 0.9877, val acc = 0.9726
# epoch =  8, train acc = 0.9950, val acc = 0.9791
# epoch =  9, train acc = 0.9925, val acc = 0.9761
# epoch = 10, train acc = 0.9942, val acc = 0.9771
# epoch = 11, train acc = 0.9932, val acc = 0.9748
# epoch = 12, train acc = 0.9931, val acc = 0.9764
# epoch = 13, train acc = 0.9972, val acc = 0.9793
# epoch = 14, train acc = 0.9968, val acc = 0.9802
# epoch = 15, train acc = 0.9961, val acc = 0.9781
# epoch = 16, train acc = 0.9906, val acc = 0.9740
# epoch = 17, train acc = 0.9977, val acc = 0.9796
# epoch = 18, train acc = 0.9980, val acc = 0.9808
# epoch = 19, train acc = 0.9984, val acc = 0.9809
# epoch = 20, train acc = 0.9935, val acc = 0.9764
# epoch = 21, train acc = 0.9977, val acc = 0.9805
# epoch = 22, train acc = 0.9983, val acc = 0.9808
# epoch = 23, train acc = 0.9917, val acc = 0.9734
# epoch = 24, train acc = 0.9937, val acc = 0.9759
# epoch = 25, train acc = 0.9971, val acc = 0.9810
# epoch = 26, train acc = 0.9960, val acc = 0.9761
# epoch = 27, train acc = 0.9952, val acc = 0.9773
# epoch = 28, train acc = 0.9965, val acc = 0.9800
# epoch = 29, train acc = 0.9979, val acc = 0.9807
# epoch = 30, train acc = 0.9969, val acc = 0.9807
# epoch = 31, train acc = 0.9974, val acc = 0.9805
# epoch = 32, train acc = 0.9971, val acc = 0.9794
# epoch = 33, train acc = 0.9983, val acc = 0.9815
# epoch = 34, train acc = 0.9993, val acc = 0.9823
# epoch = 35, train acc = 0.9979, val acc = 0.9796
# epoch = 36, train acc = 0.9997, val acc = 0.9830
# epoch = 37, train acc = 0.9915, val acc = 0.9742
# epoch = 38, train acc = 0.9945, val acc = 0.9774
# epoch = 39, train acc = 0.9901, val acc = 0.9733
# epoch = 40, train acc = 0.9967, val acc = 0.9806
# epoch = 41, train acc = 0.9983, val acc = 0.9808
# epoch = 42, train acc = 0.9940, val acc = 0.9791
# epoch = 43, train acc = 0.9967, val acc = 0.9783
# epoch = 44, train acc = 0.9938, val acc = 0.9744
# epoch = 45, train acc = 0.9982, val acc = 0.9801
# epoch = 46, train acc = 0.9998, val acc = 0.9828
# epoch = 47, train acc = 1.0000, val acc = 0.9843
# epoch = 48, train acc = 0.9999, val acc = 0.9827
# epoch = 49, train acc = 1.0000, val acc = 0.9833
#
# Training with and lr = 0.1 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9413, val acc = 0.9393
# epoch =  1, train acc = 0.9740, val acc = 0.9665
# epoch =  2, train acc = 0.9778, val acc = 0.9720
# epoch =  3, train acc = 0.9867, val acc = 0.9735
# epoch =  4, train acc = 0.9890, val acc = 0.9761
# epoch =  5, train acc = 0.9877, val acc = 0.9716
# epoch =  6, train acc = 0.9832, val acc = 0.9700
# epoch =  7, train acc = 0.9903, val acc = 0.9742
# epoch =  8, train acc = 0.9950, val acc = 0.9771
# epoch =  9, train acc = 0.9948, val acc = 0.9788
# epoch = 10, train acc = 0.9898, val acc = 0.9735
# epoch = 11, train acc = 0.9957, val acc = 0.9789
# epoch = 12, train acc = 0.9958, val acc = 0.9792
# epoch = 13, train acc = 0.9934, val acc = 0.9775
# epoch = 14, train acc = 0.9963, val acc = 0.9783
# epoch = 15, train acc = 0.9935, val acc = 0.9772
# epoch = 16, train acc = 0.9939, val acc = 0.9760
# epoch = 17, train acc = 0.9908, val acc = 0.9734
# epoch = 18, train acc = 0.9959, val acc = 0.9792
# epoch = 19, train acc = 0.9934, val acc = 0.9754
# epoch = 20, train acc = 0.9966, val acc = 0.9799
# epoch = 21, train acc = 0.9966, val acc = 0.9793
# epoch = 22, train acc = 0.9971, val acc = 0.9804
# epoch = 23, train acc = 0.9948, val acc = 0.9769
# epoch = 24, train acc = 0.9953, val acc = 0.9790
# epoch = 25, train acc = 0.9968, val acc = 0.9805
# epoch = 26, train acc = 0.9967, val acc = 0.9797
# epoch = 27, train acc = 0.9966, val acc = 0.9786
# epoch = 28, train acc = 0.9935, val acc = 0.9767
# epoch = 29, train acc = 0.9954, val acc = 0.9791
# epoch = 30, train acc = 0.9957, val acc = 0.9763
# epoch = 31, train acc = 0.9927, val acc = 0.9762
# epoch = 32, train acc = 0.9928, val acc = 0.9758
# epoch = 33, train acc = 0.9975, val acc = 0.9798
# epoch = 34, train acc = 0.9960, val acc = 0.9777
# epoch = 35, train acc = 0.9975, val acc = 0.9815
# epoch = 36, train acc = 0.9964, val acc = 0.9790
# epoch = 37, train acc = 0.9871, val acc = 0.9705
# epoch = 38, train acc = 0.9994, val acc = 0.9829
# epoch = 39, train acc = 0.9998, val acc = 0.9818
# epoch = 40, train acc = 0.9998, val acc = 0.9819
# epoch = 41, train acc = 1.0000, val acc = 0.9841
# epoch = 42, train acc = 1.0000, val acc = 0.9837
# epoch = 43, train acc = 1.0000, val acc = 0.9835
# epoch = 44, train acc = 0.9999, val acc = 0.9844
# epoch = 45, train acc = 1.0000, val acc = 0.9842
# epoch = 46, train acc = 0.9510, val acc = 0.9410
# epoch = 47, train acc = 0.9817, val acc = 0.9698
# epoch = 48, train acc = 0.9953, val acc = 0.9784
# epoch = 49, train acc = 0.9955, val acc = 0.9779
#
# Training with and lr = 0.3 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9463, val acc = 0.9473
# epoch =  1, train acc = 0.9721, val acc = 0.9656
# epoch =  2, train acc = 0.9759, val acc = 0.9686
# epoch =  3, train acc = 0.9843, val acc = 0.9762
# epoch =  4, train acc = 0.9826, val acc = 0.9712
# epoch =  5, train acc = 0.9835, val acc = 0.9709
# epoch =  6, train acc = 0.9884, val acc = 0.9734
# epoch =  7, train acc = 0.9827, val acc = 0.9702
# epoch =  8, train acc = 0.9873, val acc = 0.9731
# epoch =  9, train acc = 0.9941, val acc = 0.9778
# epoch = 10, train acc = 0.9915, val acc = 0.9760
# epoch = 11, train acc = 0.9924, val acc = 0.9776
# epoch = 12, train acc = 0.9908, val acc = 0.9777
# epoch = 13, train acc = 0.9921, val acc = 0.9763
# epoch = 14, train acc = 0.9773, val acc = 0.9661
# epoch = 15, train acc = 0.9947, val acc = 0.9786
# epoch = 16, train acc = 0.9925, val acc = 0.9768
# epoch = 17, train acc = 0.9914, val acc = 0.9736
# epoch = 18, train acc = 0.9954, val acc = 0.9785
# epoch = 19, train acc = 0.9946, val acc = 0.9770
# epoch = 20, train acc = 0.9885, val acc = 0.9721
# epoch = 21, train acc = 0.9931, val acc = 0.9760
# epoch = 22, train acc = 0.9949, val acc = 0.9802
# epoch = 23, train acc = 0.9950, val acc = 0.9770
# epoch = 24, train acc = 0.9870, val acc = 0.9679
# epoch = 25, train acc = 0.9913, val acc = 0.9737
# epoch = 26, train acc = 0.9971, val acc = 0.9805
# epoch = 27, train acc = 0.9936, val acc = 0.9758
# epoch = 28, train acc = 0.9944, val acc = 0.9761
# epoch = 29, train acc = 0.9946, val acc = 0.9774
# epoch = 30, train acc = 0.9940, val acc = 0.9775
# epoch = 31, train acc = 0.9900, val acc = 0.9732
# epoch = 32, train acc = 0.9923, val acc = 0.9762
# epoch = 33, train acc = 0.9926, val acc = 0.9758
# epoch = 34, train acc = 0.9921, val acc = 0.9746
# epoch = 35, train acc = 0.9910, val acc = 0.9764
# epoch = 36, train acc = 0.9961, val acc = 0.9813
# epoch = 37, train acc = 0.9930, val acc = 0.9770
# epoch = 38, train acc = 0.9917, val acc = 0.9726
# epoch = 39, train acc = 0.9933, val acc = 0.9760
# epoch = 40, train acc = 0.9848, val acc = 0.9684
# epoch = 41, train acc = 0.9970, val acc = 0.9791
# epoch = 42, train acc = 0.9954, val acc = 0.9789
# epoch = 43, train acc = 0.9873, val acc = 0.9687
# epoch = 44, train acc = 0.9937, val acc = 0.9753
# epoch = 45, train acc = 0.9877, val acc = 0.9688
# epoch = 46, train acc = 0.9959, val acc = 0.9777
# epoch = 47, train acc = 0.9973, val acc = 0.9792
# epoch = 48, train acc = 0.9936, val acc = 0.9776
# epoch = 49, train acc = 0.9978, val acc = 0.9795
#
# Training with and lr = 0.5 and alpha = 3e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9374, val acc = 0.9404
# epoch =  1, train acc = 0.9465, val acc = 0.9460
# epoch =  2, train acc = 0.9649, val acc = 0.9639
# epoch =  3, train acc = 0.9732, val acc = 0.9671
# epoch =  4, train acc = 0.9744, val acc = 0.9643
# epoch =  5, train acc = 0.9776, val acc = 0.9694
# epoch =  6, train acc = 0.9816, val acc = 0.9709
# epoch =  7, train acc = 0.9786, val acc = 0.9691
# epoch =  8, train acc = 0.9810, val acc = 0.9672
# epoch =  9, train acc = 0.9872, val acc = 0.9741
# epoch = 10, train acc = 0.9870, val acc = 0.9737
# epoch = 11, train acc = 0.9883, val acc = 0.9732
# epoch = 12, train acc = 0.9847, val acc = 0.9709
# epoch = 13, train acc = 0.9841, val acc = 0.9714
# epoch = 14, train acc = 0.9812, val acc = 0.9678
# epoch = 15, train acc = 0.9863, val acc = 0.9720
# epoch = 16, train acc = 0.9903, val acc = 0.9739
# epoch = 17, train acc = 0.9798, val acc = 0.9635
# epoch = 18, train acc = 0.9893, val acc = 0.9736
# epoch = 19, train acc = 0.9841, val acc = 0.9670
# epoch = 20, train acc = 0.9888, val acc = 0.9743
# epoch = 21, train acc = 0.9907, val acc = 0.9735
# epoch = 22, train acc = 0.9901, val acc = 0.9731
# epoch = 23, train acc = 0.9524, val acc = 0.9352
# epoch = 24, train acc = 0.9887, val acc = 0.9732
# epoch = 25, train acc = 0.9800, val acc = 0.9656
# epoch = 26, train acc = 0.9800, val acc = 0.9652
# epoch = 27, train acc = 0.9888, val acc = 0.9701
# epoch = 28, train acc = 0.9877, val acc = 0.9715
# epoch = 29, train acc = 0.9777, val acc = 0.9669
# epoch = 30, train acc = 0.9914, val acc = 0.9736
# epoch = 31, train acc = 0.9897, val acc = 0.9743
# epoch = 32, train acc = 0.9904, val acc = 0.9762
# epoch = 33, train acc = 0.9886, val acc = 0.9749
# epoch = 34, train acc = 0.9917, val acc = 0.9770
# epoch = 35, train acc = 0.9884, val acc = 0.9737
# epoch = 36, train acc = 0.9930, val acc = 0.9762
# epoch = 37, train acc = 0.9912, val acc = 0.9750
# epoch = 38, train acc = 0.9893, val acc = 0.9727
# epoch = 39, train acc = 0.9927, val acc = 0.9747
# epoch = 40, train acc = 0.9882, val acc = 0.9687
# epoch = 41, train acc = 0.9918, val acc = 0.9753
# epoch = 42, train acc = 0.9931, val acc = 0.9788
# epoch = 43, train acc = 0.9881, val acc = 0.9722
# epoch = 44, train acc = 0.9915, val acc = 0.9743
# epoch = 45, train acc = 0.9865, val acc = 0.9725
# epoch = 46, train acc = 0.9855, val acc = 0.9710
# epoch = 47, train acc = 0.9944, val acc = 0.9750
# epoch = 48, train acc = 0.9927, val acc = 0.9758
# epoch = 49, train acc = 0.9931, val acc = 0.9762
#
# Training with and lr = 0.07 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9567, val acc = 0.9573
# epoch =  1, train acc = 0.9733, val acc = 0.9683
# epoch =  2, train acc = 0.9769, val acc = 0.9699
# epoch =  3, train acc = 0.9838, val acc = 0.9736
# epoch =  4, train acc = 0.9846, val acc = 0.9745
# epoch =  5, train acc = 0.9851, val acc = 0.9723
# epoch =  6, train acc = 0.9821, val acc = 0.9707
# epoch =  7, train acc = 0.9851, val acc = 0.9710
# epoch =  8, train acc = 0.9922, val acc = 0.9785
# epoch =  9, train acc = 0.9930, val acc = 0.9779
# epoch = 10, train acc = 0.9898, val acc = 0.9769
# epoch = 11, train acc = 0.9912, val acc = 0.9794
# epoch = 12, train acc = 0.9915, val acc = 0.9769
# epoch = 13, train acc = 0.9893, val acc = 0.9738
# epoch = 14, train acc = 0.9909, val acc = 0.9750
# epoch = 15, train acc = 0.9929, val acc = 0.9791
# epoch = 16, train acc = 0.9918, val acc = 0.9776
# epoch = 17, train acc = 0.9935, val acc = 0.9778
# epoch = 18, train acc = 0.9951, val acc = 0.9802
# epoch = 19, train acc = 0.9849, val acc = 0.9724
# epoch = 20, train acc = 0.9943, val acc = 0.9802
# epoch = 21, train acc = 0.9902, val acc = 0.9744
# epoch = 22, train acc = 0.9919, val acc = 0.9782
# epoch = 23, train acc = 0.9935, val acc = 0.9775
# epoch = 24, train acc = 0.9946, val acc = 0.9784
# epoch = 25, train acc = 0.9963, val acc = 0.9805
# epoch = 26, train acc = 0.9953, val acc = 0.9797
# epoch = 27, train acc = 0.9919, val acc = 0.9770
# epoch = 28, train acc = 0.9941, val acc = 0.9800
# epoch = 29, train acc = 0.9961, val acc = 0.9798
# epoch = 30, train acc = 0.9931, val acc = 0.9777
# epoch = 31, train acc = 0.9858, val acc = 0.9718
# epoch = 32, train acc = 0.9812, val acc = 0.9685
# epoch = 33, train acc = 0.9912, val acc = 0.9787
# epoch = 34, train acc = 0.9953, val acc = 0.9791
# epoch = 35, train acc = 0.9923, val acc = 0.9757
# epoch = 36, train acc = 0.9955, val acc = 0.9788
# epoch = 37, train acc = 0.9918, val acc = 0.9745
# epoch = 38, train acc = 0.9937, val acc = 0.9781
# epoch = 39, train acc = 0.9950, val acc = 0.9813
# epoch = 40, train acc = 0.9960, val acc = 0.9813
# epoch = 41, train acc = 0.9956, val acc = 0.9784
# epoch = 42, train acc = 0.9962, val acc = 0.9794
# epoch = 43, train acc = 0.9960, val acc = 0.9795
# epoch = 44, train acc = 0.9954, val acc = 0.9807
# epoch = 45, train acc = 0.9867, val acc = 0.9717
# epoch = 46, train acc = 0.9798, val acc = 0.9643
# epoch = 47, train acc = 0.9873, val acc = 0.9698
# epoch = 48, train acc = 0.9957, val acc = 0.9783
# epoch = 49, train acc = 0.9951, val acc = 0.9773
#
# Training with and lr = 0.1 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9499, val acc = 0.9503
# epoch =  1, train acc = 0.9763, val acc = 0.9703
# epoch =  2, train acc = 0.9815, val acc = 0.9726
# epoch =  3, train acc = 0.9819, val acc = 0.9696
# epoch =  4, train acc = 0.9814, val acc = 0.9690
# epoch =  5, train acc = 0.9767, val acc = 0.9661
# epoch =  6, train acc = 0.9911, val acc = 0.9786
# epoch =  7, train acc = 0.9913, val acc = 0.9761
# epoch =  8, train acc = 0.9889, val acc = 0.9765
# epoch =  9, train acc = 0.9789, val acc = 0.9676
# epoch = 10, train acc = 0.9717, val acc = 0.9580
# epoch = 11, train acc = 0.9882, val acc = 0.9744
# epoch = 12, train acc = 0.9889, val acc = 0.9746
# epoch = 13, train acc = 0.9902, val acc = 0.9751
# epoch = 14, train acc = 0.9905, val acc = 0.9762
# epoch = 15, train acc = 0.9937, val acc = 0.9788
# epoch = 16, train acc = 0.9886, val acc = 0.9749
# epoch = 17, train acc = 0.9899, val acc = 0.9731
# epoch = 18, train acc = 0.9848, val acc = 0.9715
# epoch = 19, train acc = 0.9934, val acc = 0.9779
# epoch = 20, train acc = 0.9893, val acc = 0.9730
# epoch = 21, train acc = 0.9911, val acc = 0.9758
# epoch = 22, train acc = 0.9908, val acc = 0.9768
# epoch = 23, train acc = 0.9941, val acc = 0.9784
# epoch = 24, train acc = 0.9925, val acc = 0.9773
# epoch = 25, train acc = 0.9908, val acc = 0.9744
# epoch = 26, train acc = 0.9948, val acc = 0.9766
# epoch = 27, train acc = 0.9938, val acc = 0.9762
# epoch = 28, train acc = 0.9875, val acc = 0.9728
# epoch = 29, train acc = 0.9882, val acc = 0.9746
# epoch = 30, train acc = 0.9888, val acc = 0.9753
# epoch = 31, train acc = 0.9952, val acc = 0.9791
# epoch = 32, train acc = 0.9945, val acc = 0.9778
# epoch = 33, train acc = 0.9877, val acc = 0.9706
# epoch = 34, train acc = 0.9831, val acc = 0.9673
# epoch = 35, train acc = 0.9939, val acc = 0.9781
# epoch = 36, train acc = 0.9898, val acc = 0.9745
# epoch = 37, train acc = 0.9937, val acc = 0.9771
# epoch = 38, train acc = 0.9750, val acc = 0.9632
# epoch = 39, train acc = 0.9941, val acc = 0.9766
# epoch = 40, train acc = 0.9939, val acc = 0.9798
# epoch = 41, train acc = 0.9948, val acc = 0.9796
# epoch = 42, train acc = 0.9942, val acc = 0.9768
# epoch = 43, train acc = 0.9916, val acc = 0.9766
# epoch = 44, train acc = 0.9920, val acc = 0.9768
# epoch = 45, train acc = 0.9920, val acc = 0.9769
# epoch = 46, train acc = 0.9939, val acc = 0.9795
# epoch = 47, train acc = 0.9945, val acc = 0.9781
# epoch = 48, train acc = 0.9916, val acc = 0.9751
# epoch = 49, train acc = 0.9938, val acc = 0.9783
#
# Training with and lr = 0.3 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9518, val acc = 0.9529
# epoch =  1, train acc = 0.9672, val acc = 0.9669
# epoch =  2, train acc = 0.9714, val acc = 0.9635
# epoch =  3, train acc = 0.9771, val acc = 0.9678
# epoch =  4, train acc = 0.9780, val acc = 0.9694
# epoch =  5, train acc = 0.9601, val acc = 0.9550
# epoch =  6, train acc = 0.9751, val acc = 0.9627
# epoch =  7, train acc = 0.9780, val acc = 0.9696
# epoch =  8, train acc = 0.9834, val acc = 0.9697
# epoch =  9, train acc = 0.9757, val acc = 0.9636
# epoch = 10, train acc = 0.9819, val acc = 0.9698
# epoch = 11, train acc = 0.9672, val acc = 0.9503
# epoch = 12, train acc = 0.9904, val acc = 0.9779
# epoch = 13, train acc = 0.9897, val acc = 0.9775
# epoch = 14, train acc = 0.9859, val acc = 0.9748
# epoch = 15, train acc = 0.9900, val acc = 0.9766
# epoch = 16, train acc = 0.9764, val acc = 0.9626
# epoch = 17, train acc = 0.9895, val acc = 0.9738
# epoch = 18, train acc = 0.9848, val acc = 0.9711
# epoch = 19, train acc = 0.9878, val acc = 0.9746
# epoch = 20, train acc = 0.9842, val acc = 0.9688
# epoch = 21, train acc = 0.9855, val acc = 0.9724
# epoch = 22, train acc = 0.9909, val acc = 0.9758
# epoch = 23, train acc = 0.9833, val acc = 0.9691
# epoch = 24, train acc = 0.9879, val acc = 0.9737
# epoch = 25, train acc = 0.9825, val acc = 0.9712
# epoch = 26, train acc = 0.9756, val acc = 0.9638
# epoch = 27, train acc = 0.9651, val acc = 0.9508
# epoch = 28, train acc = 0.9911, val acc = 0.9762
# epoch = 29, train acc = 0.9837, val acc = 0.9719
# epoch = 30, train acc = 0.9826, val acc = 0.9660
# epoch = 31, train acc = 0.9922, val acc = 0.9779
# epoch = 32, train acc = 0.9915, val acc = 0.9792
# epoch = 33, train acc = 0.9920, val acc = 0.9795
# epoch = 34, train acc = 0.9822, val acc = 0.9716
# epoch = 35, train acc = 0.9894, val acc = 0.9731
# epoch = 36, train acc = 0.9938, val acc = 0.9783
# epoch = 37, train acc = 0.9939, val acc = 0.9766
# epoch = 38, train acc = 0.9768, val acc = 0.9641
# epoch = 39, train acc = 0.9931, val acc = 0.9786
# epoch = 40, train acc = 0.9916, val acc = 0.9776
# epoch = 41, train acc = 0.9898, val acc = 0.9753
# epoch = 42, train acc = 0.9865, val acc = 0.9708
# epoch = 43, train acc = 0.9841, val acc = 0.9680
# epoch = 44, train acc = 0.9795, val acc = 0.9655
# epoch = 45, train acc = 0.9919, val acc = 0.9772
# epoch = 46, train acc = 0.9918, val acc = 0.9784
# epoch = 47, train acc = 0.9915, val acc = 0.9768
# epoch = 48, train acc = 0.9839, val acc = 0.9696
# epoch = 49, train acc = 0.9885, val acc = 0.9742
#
# Training with and lr = 0.5 and alpha = 7e-05 for n_epochs = 50
# epoch =  0, train acc = 0.9408, val acc = 0.9451
# epoch =  1, train acc = 0.9493, val acc = 0.9479
# epoch =  2, train acc = 0.9270, val acc = 0.9264
# epoch =  3, train acc = 0.9683, val acc = 0.9623
# epoch =  4, train acc = 0.9736, val acc = 0.9658
# epoch =  5, train acc = 0.9781, val acc = 0.9668
# epoch =  6, train acc = 0.9796, val acc = 0.9716
# epoch =  7, train acc = 0.9744, val acc = 0.9641
# epoch =  8, train acc = 0.9794, val acc = 0.9705
# epoch =  9, train acc = 0.9813, val acc = 0.9673
# epoch = 10, train acc = 0.9850, val acc = 0.9721
# epoch = 11, train acc = 0.9752, val acc = 0.9662
# epoch = 12, train acc = 0.9844, val acc = 0.9734
# epoch = 13, train acc = 0.9838, val acc = 0.9733
# epoch = 14, train acc = 0.9824, val acc = 0.9681
# epoch = 15, train acc = 0.9786, val acc = 0.9644
# epoch = 16, train acc = 0.9885, val acc = 0.9752
# epoch = 17, train acc = 0.9824, val acc = 0.9711
# epoch = 18, train acc = 0.9832, val acc = 0.9727
# epoch = 19, train acc = 0.9835, val acc = 0.9705
# epoch = 20, train acc = 0.9817, val acc = 0.9675
# epoch = 21, train acc = 0.9828, val acc = 0.9694
# epoch = 22, train acc = 0.9823, val acc = 0.9713
# epoch = 23, train acc = 0.9805, val acc = 0.9674
# epoch = 24, train acc = 0.9740, val acc = 0.9626
# epoch = 25, train acc = 0.9824, val acc = 0.9726
# epoch = 26, train acc = 0.9808, val acc = 0.9693
# epoch = 27, train acc = 0.9814, val acc = 0.9697
# epoch = 28, train acc = 0.9865, val acc = 0.9717
# epoch = 29, train acc = 0.9827, val acc = 0.9711
# epoch = 30, train acc = 0.9853, val acc = 0.9714
# epoch = 31, train acc = 0.9887, val acc = 0.9764
# epoch = 32, train acc = 0.9871, val acc = 0.9748
# epoch = 33, train acc = 0.9809, val acc = 0.9715
# epoch = 34, train acc = 0.9862, val acc = 0.9735
# epoch = 35, train acc = 0.9744, val acc = 0.9632
# epoch = 36, train acc = 0.9880, val acc = 0.9741
# epoch = 37, train acc = 0.9855, val acc = 0.9737
# epoch = 38, train acc = 0.9903, val acc = 0.9761
# epoch = 39, train acc = 0.9778, val acc = 0.9636
# epoch = 40, train acc = 0.9877, val acc = 0.9729
# epoch = 41, train acc = 0.9542, val acc = 0.9454
# epoch = 42, train acc = 0.9798, val acc = 0.9689
# epoch = 43, train acc = 0.9894, val acc = 0.9754
# epoch = 44, train acc = 0.9886, val acc = 0.9748
# epoch = 45, train acc = 0.9889, val acc = 0.9758
# epoch = 46, train acc = 0.9877, val acc = 0.9746
# epoch = 47, train acc = 0.9874, val acc = 0.9741
# epoch = 48, train acc = 0.9897, val acc = 0.9754
# epoch = 49, train acc = 0.9871, val acc = 0.9743
#
# Training with and lr = 0.07 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9521, val acc = 0.9514
# epoch =  1, train acc = 0.9694, val acc = 0.9636
# epoch =  2, train acc = 0.9789, val acc = 0.9709
# epoch =  3, train acc = 0.9818, val acc = 0.9728
# epoch =  4, train acc = 0.9776, val acc = 0.9672
# epoch =  5, train acc = 0.9839, val acc = 0.9749
# epoch =  6, train acc = 0.9890, val acc = 0.9769
# epoch =  7, train acc = 0.9865, val acc = 0.9722
# epoch =  8, train acc = 0.9913, val acc = 0.9785
# epoch =  9, train acc = 0.9871, val acc = 0.9764
# epoch = 10, train acc = 0.9859, val acc = 0.9745
# epoch = 11, train acc = 0.9902, val acc = 0.9763
# epoch = 12, train acc = 0.9843, val acc = 0.9717
# epoch = 13, train acc = 0.9919, val acc = 0.9790
# epoch = 14, train acc = 0.9909, val acc = 0.9761
# epoch = 15, train acc = 0.9864, val acc = 0.9751
# epoch = 16, train acc = 0.9879, val acc = 0.9738
# epoch = 17, train acc = 0.9921, val acc = 0.9795
# epoch = 18, train acc = 0.9777, val acc = 0.9662
# epoch = 19, train acc = 0.9926, val acc = 0.9778
# epoch = 20, train acc = 0.9905, val acc = 0.9775
# epoch = 21, train acc = 0.9922, val acc = 0.9791
# epoch = 22, train acc = 0.9937, val acc = 0.9788
# epoch = 23, train acc = 0.9920, val acc = 0.9772
# epoch = 24, train acc = 0.9882, val acc = 0.9757
# epoch = 25, train acc = 0.9923, val acc = 0.9796
# epoch = 26, train acc = 0.9870, val acc = 0.9733
# epoch = 27, train acc = 0.9886, val acc = 0.9729
# epoch = 28, train acc = 0.9910, val acc = 0.9767
# epoch = 29, train acc = 0.9930, val acc = 0.9791
# epoch = 30, train acc = 0.9832, val acc = 0.9667
# epoch = 31, train acc = 0.9906, val acc = 0.9792
# epoch = 32, train acc = 0.9885, val acc = 0.9764
# epoch = 33, train acc = 0.9885, val acc = 0.9737
# epoch = 34, train acc = 0.9857, val acc = 0.9725
# epoch = 35, train acc = 0.9925, val acc = 0.9799
# epoch = 36, train acc = 0.9937, val acc = 0.9784
# epoch = 37, train acc = 0.9842, val acc = 0.9709
# epoch = 38, train acc = 0.9886, val acc = 0.9748
# epoch = 39, train acc = 0.9913, val acc = 0.9774
# epoch = 40, train acc = 0.9917, val acc = 0.9759
# epoch = 41, train acc = 0.9902, val acc = 0.9794
# epoch = 42, train acc = 0.9922, val acc = 0.9796
# epoch = 43, train acc = 0.9917, val acc = 0.9784
# epoch = 44, train acc = 0.9935, val acc = 0.9784
# epoch = 45, train acc = 0.9882, val acc = 0.9750
# epoch = 46, train acc = 0.9915, val acc = 0.9758
# epoch = 47, train acc = 0.9489, val acc = 0.9404
# epoch = 48, train acc = 0.9907, val acc = 0.9757
# epoch = 49, train acc = 0.9942, val acc = 0.9796
#
# Training with and lr = 0.1 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9501, val acc = 0.9485
# epoch =  1, train acc = 0.9649, val acc = 0.9615
# epoch =  2, train acc = 0.9783, val acc = 0.9701
# epoch =  3, train acc = 0.9779, val acc = 0.9704
# epoch =  4, train acc = 0.9840, val acc = 0.9736
# epoch =  5, train acc = 0.9848, val acc = 0.9760
# epoch =  6, train acc = 0.9890, val acc = 0.9793
# epoch =  7, train acc = 0.9885, val acc = 0.9764
# epoch =  8, train acc = 0.9825, val acc = 0.9711
# epoch =  9, train acc = 0.9772, val acc = 0.9677
# epoch = 10, train acc = 0.9887, val acc = 0.9771
# epoch = 11, train acc = 0.9911, val acc = 0.9771
# epoch = 12, train acc = 0.9887, val acc = 0.9750
# epoch = 13, train acc = 0.9845, val acc = 0.9722
# epoch = 14, train acc = 0.9923, val acc = 0.9777
# epoch = 15, train acc = 0.9834, val acc = 0.9725
# epoch = 16, train acc = 0.9888, val acc = 0.9745
# epoch = 17, train acc = 0.9869, val acc = 0.9745
# epoch = 18, train acc = 0.9916, val acc = 0.9791
# epoch = 19, train acc = 0.9922, val acc = 0.9781
# epoch = 20, train acc = 0.9905, val acc = 0.9762
# epoch = 21, train acc = 0.9907, val acc = 0.9779
# epoch = 22, train acc = 0.9919, val acc = 0.9786
# epoch = 23, train acc = 0.9866, val acc = 0.9723
# epoch = 24, train acc = 0.9905, val acc = 0.9766
# epoch = 25, train acc = 0.9935, val acc = 0.9799
# epoch = 26, train acc = 0.9853, val acc = 0.9714
# epoch = 27, train acc = 0.9873, val acc = 0.9739
# epoch = 28, train acc = 0.9947, val acc = 0.9801
# epoch = 29, train acc = 0.9910, val acc = 0.9768
# epoch = 30, train acc = 0.9855, val acc = 0.9729
# epoch = 31, train acc = 0.9817, val acc = 0.9695
# epoch = 32, train acc = 0.9913, val acc = 0.9773
# epoch = 33, train acc = 0.9907, val acc = 0.9762
# epoch = 34, train acc = 0.9643, val acc = 0.9536
# epoch = 35, train acc = 0.9843, val acc = 0.9704
# epoch = 36, train acc = 0.9904, val acc = 0.9784
# epoch = 37, train acc = 0.9929, val acc = 0.9790
# epoch = 38, train acc = 0.9920, val acc = 0.9783
# epoch = 39, train acc = 0.9797, val acc = 0.9677
# epoch = 40, train acc = 0.9928, val acc = 0.9777
# epoch = 41, train acc = 0.9883, val acc = 0.9712
# epoch = 42, train acc = 0.9893, val acc = 0.9752
# epoch = 43, train acc = 0.9900, val acc = 0.9755
# epoch = 44, train acc = 0.9912, val acc = 0.9772
# epoch = 45, train acc = 0.9916, val acc = 0.9763
# epoch = 46, train acc = 0.9913, val acc = 0.9798
# epoch = 47, train acc = 0.9901, val acc = 0.9795
# epoch = 48, train acc = 0.9864, val acc = 0.9721
# epoch = 49, train acc = 0.9926, val acc = 0.9805
#
# Training with and lr = 0.3 and alpha = 0.0001 for n_epochs = 50
# epoch =  0, train acc = 0.9559, val acc = 0.9555
# epoch =  1, train acc = 0.9614, val acc = 0.9559
# epoch =  2, train acc = 0.9651, val acc = 0.9620
# epoch =  3, train acc = 0.9764, val acc = 0.9680
# epoch =  4, train acc = 0.9783, val acc = 0.9708
# epoch =  5, train acc = 0.9656, val acc = 0.9620
# epoch =  6, train acc = 0.9777, val acc = 0.9701
# epoch =  7, train acc = 0.9779, val acc = 0.9683
# epoch =  8, train acc = 0.9829, val acc = 0.9745
# epoch =  9, train acc = 0.9816, val acc = 0.9698
# epoch = 10, train acc = 0.9840, val acc = 0.9714
# epoch = 11, train acc = 0.9871, val acc = 0.9750
# epoch = 12, train acc = 0.9684, val acc = 0.9580
# epoch = 13, train acc = 0.9856, val acc = 0.9751
# epoch = 14, train acc = 0.9774, val acc = 0.9651
# epoch = 15, train acc = 0.9847, val acc = 0.9742
# epoch = 16, train acc = 0.9840, val acc = 0.9730
# epoch = 17, train acc = 0.9897, val acc = 0.9775
# epoch = 18, train acc = 0.9906, val acc = 0.9773
# epoch = 19, train acc = 0.9850, val acc = 0.9724
# epoch = 20, train acc = 0.9876, val acc = 0.9743
# epoch = 21, train acc = 0.9900, val acc = 0.9772
# epoch = 22, train acc = 0.9876, val acc = 0.9754
# epoch = 23, train acc = 0.9845, val acc = 0.9694
# epoch = 24, train acc = 0.9906, val acc = 0.9763
# epoch = 25, train acc = 0.9874, val acc = 0.9733
# epoch = 26, train acc = 0.9834, val acc = 0.9709
# epoch = 27, train acc = 0.9907, val acc = 0.9762
# epoch = 28, train acc = 0.9819, val acc = 0.9718
# epoch = 29, train acc = 0.9886, val acc = 0.9760
# epoch = 30, train acc = 0.9852, val acc = 0.9744
# epoch = 31, train acc = 0.9893, val acc = 0.9778
# epoch = 32, train acc = 0.9918, val acc = 0.9777
# epoch = 33, train acc = 0.9869, val acc = 0.9753
# epoch = 34, train acc = 0.9644, val acc = 0.9567
# epoch = 35, train acc = 0.9860, val acc = 0.9753
# epoch = 36, train acc = 0.9909, val acc = 0.9764
# epoch = 37, train acc = 0.9831, val acc = 0.9718
# epoch = 38, train acc = 0.9849, val acc = 0.9717
# epoch = 39, train acc = 0.9818, val acc = 0.9706
# epoch = 40, train acc = 0.9888, val acc = 0.9781
# epoch = 41, train acc = 0.9886, val acc = 0.9764
# epoch = 42, train acc = 0.9866, val acc = 0.9758
# epoch = 43, train acc = 0.9842, val acc = 0.9716
# epoch = 44, train acc = 0.9827, val acc = 0.9708
# epoch = 45, train acc = 0.9662, val acc = 0.9588
# epoch = 46, train acc = 0.9885, val acc = 0.9764
# epoch = 47, train acc = 0.9710, val acc = 0.9611
# epoch = 48, train acc = 0.9886, val acc = 0.9737
# epoch = 49, train acc = 0.9684, val acc = 0.9608
#
# Training with and lr = 0.5 and alpha = 0.0001 for n_epochs = 50
# /home/yuri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in exp
#   """
# /home/yuri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: overflow encountered in exp
#
# /home/yuri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in true_divide
#
# /home/yuri/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in greater
#   del sys.path[0]
# epoch =  0, train acc = 0.0986, val acc = 0.0991
# epoch =  1, train acc = 0.0986, val acc = 0.0991
# epoch =  2, train acc = 0.0986, val acc = 0.0991
# epoch =  3, train acc = 0.0986, val acc = 0.0991
# epoch =  4, train acc = 0.0986, val acc = 0.0991
# epoch =  5, train acc = 0.0986, val acc = 0.0991
# epoch =  6, train acc = 0.0986, val acc = 0.0991
# epoch =  7, train acc = 0.0986, val acc = 0.0991
# epoch =  8, train acc = 0.0986, val acc = 0.0991
# epoch =  9, train acc = 0.0986, val acc = 0.0991
# epoch = 10, train acc = 0.0986, val acc = 0.0991
# epoch = 11, train acc = 0.0986, val acc = 0.0991
# epoch = 12, train acc = 0.0986, val acc = 0.0991
# epoch = 13, train acc = 0.0986, val acc = 0.0991
# epoch = 14, train acc = 0.0986, val acc = 0.0991
# epoch = 15, train acc = 0.0986, val acc = 0.0991
# epoch = 16, train acc = 0.0986, val acc = 0.0991
# epoch = 17, train acc = 0.0986, val acc = 0.0991
# epoch = 18, train acc = 0.0986, val acc = 0.0991
# epoch = 19, train acc = 0.0986, val acc = 0.0991
# epoch = 20, train acc = 0.0986, val acc = 0.0991
# epoch = 21, train acc = 0.0986, val acc = 0.0991
# epoch = 22, train acc = 0.0986, val acc = 0.0991
# epoch = 23, train acc = 0.0986, val acc = 0.0991
# epoch = 24, train acc = 0.0986, val acc = 0.0991
# epoch = 25, train acc = 0.0986, val acc = 0.0991
# epoch = 26, train acc = 0.0986, val acc = 0.0991
# epoch = 27, train acc = 0.0986, val acc = 0.0991
# epoch = 28, train acc = 0.0986, val acc = 0.0991
# epoch = 29, train acc = 0.0986, val acc = 0.0991
# epoch = 30, train acc = 0.0986, val acc = 0.0991
# epoch = 31, train acc = 0.0986, val acc = 0.0991
# epoch = 32, train acc = 0.0986, val acc = 0.0991
# epoch = 33, train acc = 0.0986, val acc = 0.0991
# epoch = 34, train acc = 0.0986, val acc = 0.0991
# epoch = 35, train acc = 0.0986, val acc = 0.0991
# epoch = 36, train acc = 0.0986, val acc = 0.0991
# epoch = 37, train acc = 0.0986, val acc = 0.0991
# epoch = 38, train acc = 0.0986, val acc = 0.0991
# epoch = 39, train acc = 0.0986, val acc = 0.0991
# epoch = 40, train acc = 0.0986, val acc = 0.0991
# epoch = 41, train acc = 0.0986, val acc = 0.0991
# epoch = 42, train acc = 0.0986, val acc = 0.0991
# epoch = 43, train acc = 0.0986, val acc = 0.0991
# epoch = 44, train acc = 0.0986, val acc = 0.0991
# epoch = 45, train acc = 0.0986, val acc = 0.0991
# epoch = 46, train acc = 0.0986, val acc = 0.0991
# epoch = 47, train acc = 0.0986, val acc = 0.0991
# epoch = 48, train acc = 0.0986, val acc = 0.0991
# epoch = 49, train acc = 0.0986, val acc = 0.0991
# CPU times: user 16h 36min 22s, sys: 14h 40min 14s, total: 1d 7h 16min 37s
# Wall time: 4h 6min 36s

# %% [markdown]
# rerun with no lr = 0.5 and with alpha = 0.003 or higher

# %% [markdown]
# #### Option III:

# %%
class Dense3(Layer):
    def __init__(self, input_units, output_units, alpha=0,
                 initializer='xavier', optimizer='adam', learning_rate=0.1, beta1=0.9, beta2=0.99):
        """
        A dense layer is a layer which performs a learned affine transformation:
        f(x) = <W*x> + b
        """
        self.alpha = alpha
        
        # initialize weights with small random numbers. 
        if initializer == 'normal':
            self.weights = np.random.randn(input_units, output_units) * 0.01
        elif initializer == 'xavier':
            self.weights = np.random.randn(input_units, output_units) * np.sqrt(2 / (input_units + output_units))
        else:
            raise ValueError('Wrong initializer parameter')
        self.biases = np.zeros(output_units)
        
        
        self.optimizer = optimizer
        self.learning_rate = learning_rate
        if self.optimizer == 'momentum':
            self.beta1 = beta1
            self.momentum_weights = np.zeros_like(self.weights)
            self.momentum_biases = np.zeros_like(self.biases)        
        elif self.optimizer == 'rmsprop':
            self.beta2 = beta2
            self.epsilon=1e-08
            self.momentum_weights2 = np.zeros_like(self.weights)
            self.momentum_biases2 = np.zeros_like(self.biases)     
        elif self.optimizer == 'adam':
            self.beta1 = beta1
            self.beta2 = beta2
            self.epsilon=1e-08
            
            self.n_iterations = 0
            self.momentum_weights = np.zeros_like(self.weights)
            self.momentum_biases = np.zeros_like(self.biases)
            self.momentum_weights2 = np.zeros_like(self.weights)
            self.momentum_biases2 = np.zeros_like(self.biases)

        
        
    def forward(self,input):
        """
        Perform an affine transformation:
        f(x) = <W*x> + b
        
        input shape: [batch, input_units]
        output shape: [batch, output units]
        """
        return input.dot(self.weights) + self.biases
    
    def backward(self,input,grad_output):
        
        # compute input gradient
        grad_input = grad_output.dot(self.weights.T)
        
        # compute parameter gradient
        grad_weights = input.T.dot(grad_output)
        grad_biases = np.sum(grad_output, axis=0)
        
        # add L2 regularization
        grad_weights += self.alpha * self.weights
        
        assert grad_weights.shape == self.weights.shape and grad_biases.shape == self.biases.shape
        
        # optimization 
        if self.optimizer == 'sgd':
            self.weights -= self.learning_rate * grad_weights
            self.biases -= self.learning_rate * grad_biases
        
        elif self.optimizer == 'momentum':
            self.momentum_weights = self.beta1 * self.momentum_weights + (1 - self.beta1) * grad_weights
            self.momentum_biases = self.beta1 * self.momentum_biases + (1 - self.beta1) * grad_biases

            self.weights -= self.learning_rate * self.momentum_weights
            self.biases -= self.learning_rate * self.momentum_biases
            
        elif self.optimizer == 'rmsprop':
            self.momentum_weights2 = self.beta2 * self.momentum_weights2 + (1 - self.beta2) * grad_weights ** 2
            self.momentum_biases2 = self.beta2 * self.momentum_biases2 + (1 - self.beta2) * grad_biases ** 2

            self.weights -= self.learning_rate * grad_weights / (np.sqrt(self.momentum_weights2) + self.epsilon)
            self.biases -= self.learning_rate * grad_biases / (np.sqrt(self.momentum_biases2) + self.epsilon)

        elif self.optimizer == 'adam':
            self.n_iterations += 1
            
            self.momentum_weights = self.beta1 * self.momentum_weights + (1 - self.beta1) * grad_weights
            self.momentum_biases = self.beta1 * self.momentum_biases + (1 - self.beta1) * grad_biases
            self.momentum_weights2 = self.beta2 * self.momentum_weights2 + (1 - self.beta2) * grad_weights ** 2
            self.momentum_biases2 = self.beta2 * self.momentum_biases2 + (1 - self.beta2) * grad_biases ** 2
            
            momentum_weights_corr = self.momentum_weights / (1 - beta1 ** self.n_iterations)
            momentum_biases_corr = self.momentum_biases / (1 - beta1 ** self.n_iterations)
            
            momentum_weights2_corr = self.momentum_weights2 / (1 - beta2 ** self.n_iterations)
            momentum_biases2_corr = self.momentum_biases2 / (1 - beta2 ** self.n_iterations)

            self.weights -= self.learning_rate * momentum_weights_corr / (np.sqrt(momentum_weights2_corr) + self.epsilon)
            self.biases -= self.learning_rate * momentum_biases_corr / (np.sqrt(momentum_biases2_corr) + self.epsilon)
   
            
        return grad_input

# %%
def build_and_train3(layer_sizes, alpha, optimizer, lr, beta1, beta2, n_epochs):
    
    
    print('\nTraining with alpha = {}, optimizer = {}, lr = {}, beta1 = {} and beta2 = {} for n_epochs = {}'.format(
        alpha, optimizer, lr, beta1, beta2, n_epochs))
    
    network = []
    network.append(Dense3(X_train.shape[1], layer_sizes[0], alpha=alpha,
            optimizer=optimizer, learning_rate=lr, beta1=beta1, beta2=beta2))
    network.append(ReLU())
    for layer in range(len(layer_sizes)-1):
        network.append(Dense3(layer_sizes[layer], layer_sizes[layer+1], alpha=alpha,
            optimizer=optimizer, learning_rate=lr, beta1=beta1, beta2=beta2))
        network.append(ReLU())
    network.append(Dense3(layer_sizes[-1], 10, alpha=alpha,
            optimizer=optimizer, learning_rate=lr, beta1=beta1, beta2=beta2))

    loss_train_log = []
    loss_train = 0
    acc_train_log = []
    acc_val_log = []

    for epoch in range(n_epochs):

        for x_batch,y_batch in iterate_minibatches(X_train,y_train,batchsize=32,shuffle=True):
            loss_train_new = train(network,x_batch,y_batch)
            loss_train = 0.95 * loss_train + 0.1 * loss_train_new
        
        loss_train_log.append(loss_train)
        acc_train_log.append(np.mean(predict(network,X_train)==y_train))
        acc_val_log.append(np.mean(predict(network,X_val)==y_val))    
        print('epoch = {:2d}, train loss = {:6.4f}, train acc = {:6.4f}, val acc = {:6.4f}'.format(
            epoch, loss_train_log[-1], acc_train_log[-1], acc_val_log[-1]))
        
    return loss_train_log, acc_train_log, acc_val_log

def display_learning_curve3(ax, loss_train_log, acc_train_log, acc_val_log, alpha, optimizer, lr, beta1, beta2):
        
    ax.plot(loss_train_log / min(loss_train_log) - 0.14 , label='train loss')
    ax.plot(acc_train_log, label='train accuracy')
    ax.plot(acc_val_log, label='val accuracy')
    ax.set_ylim(0.86, 1)
#     plt.legend(loc='best')
    ax.set_title('alpha={}, opt={},\nlr={}, beta1={}, beta2={}'.format(alpha, optimizer, lr, beta1, beta2),
                 fontsize=14)
    ax.text(0.3, 0.2, 'train loss = {:6.4f}\n train acc = {:6.4f}\n    val acc = {:6.4f}'.format(
        loss_train_log[-1], acc_train_log[-1], acc_val_log[-1]),
            ha='left', va='bottom', fontsize=14, transform=ax.transAxes)
    ax.grid()
    plt.tight_layout()

# %%
# %%time
layer_sizes = [100, 200]

alpha = 0

optimizer = 'sgd'
lrs = [0.07, 0.1, 0.3]
beta1 = None
beta2 = None

n_epochs = 50


fig = plt.figure(figsize=(20, 10))
i = 0
for lr in lrs:
    i += 1
    loss_train_log, acc_train_log, acc_val_log = build_and_train3(layer_sizes, alpha=alpha,
                                          optimizer=optimizer, lr=lr, beta1=beta1, beta2=beta2, n_epochs=n_epochs)

    ax = plt.subplot(1, len(lrs), i) 
    display_learning_curve3(ax, loss_train_log, acc_train_log, acc_val_log, alpha=alpha,
                            optimizer=optimizer, lr=lr, beta1=beta1, beta2=beta2)
# Out:
# Training with alpha = 0, optimizer = sgd, lr = 0.07, beta1 = None and beta2 = None for n_epochs = 50
# epoch =  0, train loss = 0.3773, train acc = 0.9508, val acc = 0.9540
# epoch =  1, train loss = 0.2274, train acc = 0.9682, val acc = 0.9657
# epoch =  2, train loss = 0.2183, train acc = 0.9770, val acc = 0.9706
# epoch =  3, train loss = 0.1776, train acc = 0.9821, val acc = 0.9734
# epoch =  4, train loss = 0.1340, train acc = 0.9851, val acc = 0.9740
# epoch =  5, train loss = 0.1038, train acc = 0.9869, val acc = 0.9745
# epoch =  6, train loss = 0.0862, train acc = 0.9880, val acc = 0.9734
# epoch =  7, train loss = 0.1148, train acc = 0.9905, val acc = 0.9755
# epoch =  8, train loss = 0.0692, train acc = 0.9925, val acc = 0.9758
# epoch =  9, train loss = 0.0803, train acc = 0.9956, val acc = 0.9784
# epoch = 10, train loss = 0.0538, train acc = 0.9945, val acc = 0.9758
# epoch = 29, train loss = 0.0001, train acc = 1.0000, val acc = 0.9822
# epoch = 30, train loss = 0.0001, train acc = 1.0000, val acc = 0.9822
# epoch = 31, train loss = 0.0001, train acc = 1.0000, val acc = 0.9820
# epoch = 32, train loss = 0.0001, train acc = 1.0000, val acc = 0.9820
# epoch = 33, train loss = 0.0001, train acc = 1.0000, val acc = 0.9820
# epoch = 34, train loss = 0.0001, train acc = 1.0000, val acc = 0.9819
# epoch = 35, train loss = 0.0001, train acc = 1.0000, val acc = 0.9818
# epoch = 36, train loss = 0.0001, train acc = 1.0000, val acc = 0.9820
# epoch = 37, train loss = 0.0000, train acc = 1.0000, val acc = 0.9821
# epoch = 38, train loss = 0.0001, train acc = 1.0000, val acc = 0.9820
# epoch = 39, train loss = 0.0001, train acc = 1.0000, val acc = 0.9821
# epoch = 40, train loss = 0.0001, train acc = 1.0000, val acc = 0.9822
# epoch = 41, train loss = 0.0001, train acc = 1.0000, val acc = 0.9821
# epoch = 42, train loss = 0.0000, train acc = 1.0000, val acc = 0.9820
# epoch = 43, train loss = 0.0000, train acc = 1.0000, val acc = 0.9820
# epoch = 44, train loss = 0.0000, train acc = 1.0000, val acc = 0.9820
# epoch = 45, train loss = 0.0000, train acc = 1.0000, val acc = 0.9819
# epoch = 46, train loss = 0.0000, train acc = 1.0000, val acc = 0.9820
# epoch = 47, train loss = 0.0000, train acc = 1.0000, val acc = 0.9819
# epoch = 48, train loss = 0.0000, train acc = 1.0000, val acc = 0.9820
# epoch = 49, train loss = 0.0000, train acc = 1.0000, val acc = 0.9820
# CPU times: user 1h 31min 33s, sys: 2h 36min 15s, total: 4h 7min 49s
# Wall time: 35min 1s

# %%
# %%time
layer_sizes = [100, 200]

optimizer = 'momentum'
lrs = [0.07, 0.1, 0.3]
beta1s = [0.87, 0.9, 0.93]
beta2 = None
alpha = 0

n_epochs = 50


fig = plt.figure(figsize=(20, 10))
i = 0
for beta1, lr in itertools.product(beta1s, lrs):
    i += 1
    loss_train_log, acc_train_log, acc_val_log = build_and_train3(layer_sizes, alpha=alpha,
                                          optimizer=optimizer, lr=lr, beta1=beta1, beta2=beta2, n_epochs=n_epochs)

#     train_log, val_log = (0.93, 0.94, 0.95), (0.925, 0.935, 0.945 )

    ax = plt.subplot(len(beta1s), len(lrs), i)     
    display_learning_curve3(ax, loss_train_log, acc_train_log, acc_val_log, alpha=alpha,
                            optimizer=optimizer, lr=lr, beta1=beta1, beta2=beta2)
# Out:
# Training with alpha = 0, optimizer = momentum, lr = 0.07, beta1 = 0.87 and beta2 = None for n_epochs = 50
# epoch =  0, train loss = 0.3898, train acc = 0.9460, val acc = 0.9483
# epoch =  1, train loss = 0.2859, train acc = 0.9658, val acc = 0.9655
# epoch =  2, train loss = 0.2087, train acc = 0.9736, val acc = 0.9654
# epoch =  3, train loss = 0.1603, train acc = 0.9823, val acc = 0.9722
# epoch =  4, train loss = 0.1393, train acc = 0.9825, val acc = 0.9721
# epoch =  5, train loss = 0.1017, train acc = 0.9839, val acc = 0.9715
# epoch = 36, train loss = 0.0702, train acc = 0.9948, val acc = 0.9732
# epoch = 37, train loss = 0.0256, train acc = 0.9967, val acc = 0.9743
# epoch = 38, train loss = 0.0058, train acc = 0.9985, val acc = 0.9779
# epoch = 39, train loss = 0.0127, train acc = 0.9981, val acc = 0.9779
# epoch = 40, train loss = 0.0367, train acc = 0.9990, val acc = 0.9767
# epoch = 41, train loss = 0.0081, train acc = 0.9990, val acc = 0.9788
# epoch = 42, train loss = 0.0035, train acc = 0.9984, val acc = 0.9780
# epoch = 43, train loss = 0.0016, train acc = 0.9998, val acc = 0.9801
# epoch = 44, train loss = 0.0004, train acc = 1.0000, val acc = 0.9803
# epoch = 45, train loss = 0.0003, train acc = 1.0000, val acc = 0.9805
# epoch = 46, train loss = 0.0000, train acc = 1.0000, val acc = 0.9805
# epoch = 47, train loss = 0.0000, train acc = 1.0000, val acc = 0.9810
# epoch = 48, train loss = 0.0001, train acc = 1.0000, val acc = 0.9810
# epoch = 49, train loss = 0.0000, train acc = 1.0000, val acc = 0.9810
# CPU times: user 5h 14min 9s, sys: 9h 56min 43s, total: 15h 10min 52s
# Wall time: 2h 9min 55s

# %%
# %%time
layer_sizes = [100, 200]

optimizer = 'rmsprop'
lrs = [0.0007, 0.001, 0.003]
beta1 = None
beta2s = [0.87, 0.90, 0.93]
alpha = 0

n_epochs = 50

fig = plt.figure(figsize=(20, 10))
i = 0
for beta2, lr in itertools.product(beta2s, lrs):
    i += 1
    loss_train_log, acc_train_log, acc_val_log = build_and_train3(layer_sizes, alpha=alpha,
                                          optimizer=optimizer, lr=lr, beta1=beta1, beta2=beta2, n_epochs=n_epochs)

    ax = plt.subplot(len(beta1s), len(lrs), i)     
    display_learning_curve3(ax, loss_train_log, acc_train_log, acc_val_log, alpha=alpha,
                            optimizer=optimizer, lr=lr, beta1=beta1, beta2=beta2)
# Out:
# Training with alpha = 0, optimizer = rmsprop, lr = 0.0007, beta1 = None and beta2 = 0.87 for n_epochs = 50
# epoch =  0, train loss = 0.3318, train acc = 0.9575, val acc = 0.9593
# epoch =  1, train loss = 0.2023, train acc = 0.9749, val acc = 0.9705
# epoch =  2, train loss = 0.2263, train acc = 0.9761, val acc = 0.9693
# epoch =  3, train loss = 0.1616, train acc = 0.9855, val acc = 0.9750
# epoch =  4, train loss = 0.1209, train acc = 0.9859, val acc = 0.9745
# epoch =  5, train loss = 0.1032, train acc = 0.9885, val acc = 0.9757
# epoch =  6, train loss = 0.1147, train acc = 0.9907, val acc = 0.9748
# epoch =  7, train loss = 0.1677, train acc = 0.9894, val acc = 0.9737
# epoch =  8, train loss = 0.0708, train acc = 0.9922, val acc = 0.9753
# epoch =  9, train loss = 0.0492, train acc = 0.9914, val acc = 0.9746
# epoch = 10, train loss = 0.0377, train acc = 0.9946, val acc = 0.9769
# epoch = 11, train loss = 0.0504, train acc = 0.9953, val acc = 0.9776
# epoch = 12, train loss = 0.0526, train acc = 0.9960, val acc = 0.9766
# epoch = 13, train loss = 0.0975, train acc = 0.9960, val acc = 0.9783
